# %%
import pandas as pd
import os
import time
from tqdm import tqdm
import shutil
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
def folder(f_name): #this function creates a folder named "attacks" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
def find_the_way(path,file_format,con=""):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                if con in file:
                    files_add.append(os.path.join(r, file))  
            
    return files_add
path="pcaps"
files_add=find_the_way(path,'.pcap')
files_add
# Out:
# ['pcaps\\Chime_Doorbell\\2019-06-29.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-01.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-02.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-03.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-04.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-05.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-06.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-07.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-08.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-09.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-10.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-11.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-12.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-13.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-14.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-15.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-16.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-17.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-18.pcap',
#  'pcaps\\Chime_Doorbell\\2019-07-19.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-06-29.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-01.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-02.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-03.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-04.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-05.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-06.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-07.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-08.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-09.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-10.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-11.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-12.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-13.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-14.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-15.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-16.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-17.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-18.pcap',
#  'pcaps\\D-Link_Cam936L\\2019-07-19.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-06-29.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-01.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-02.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-03.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-04.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-05.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-06.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-07.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-08.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-09.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-10.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-11.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-12.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-13.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-14.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-15.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-16.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-17.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-18.pcap',
#  'pcaps\\Gosuna_LightBulb\\2019-07-19.pcap',
#  'pcaps\\Gosuna_Socket\\2019-06-29.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-01.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-02.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-03.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-04.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-05.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-06.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-07.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-08.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-09.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-10.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-11.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-12.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-13.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-14.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-15.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-16.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-17.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-18.pcap',
#  'pcaps\\Gosuna_Socket\\2019-07-19.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-06-29.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-01.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-02.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-03.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-04.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-05.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-06.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-07.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-08.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-09.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-10.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-11.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-12.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-13.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-14.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-15.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-16.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-17.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-18.pcap',
#  'pcaps\\Goumia_Coffemaker\\2019-07-19.pcap',
#  'pcaps\\itTiot_Cam\\2019-06-29.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-01.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-02.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-03.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-04.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-05.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-06.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-07.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-08.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-09.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-10.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-11.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-12.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-13.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-14.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-15.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-16.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-17.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-18.pcap',
#  'pcaps\\itTiot_Cam\\2019-07-19.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-06-29.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-01.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-02.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-03.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-04.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-05.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-06.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-07.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-08.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-09.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-10.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-11.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-12.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-13.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-14.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-15.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-16.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-17.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-18.pcap',
#  'pcaps\\LaCrosse_AlarmClock\\2019-07-19.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-06-29.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-01.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-02.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-03.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-04.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-05.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-06.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-07.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-08.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-09.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-10.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-11.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-12.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-13.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-14.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-15.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-16.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-17.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-18.pcap',
#  'pcaps\\Lumiman_Bulb600\\2019-07-19.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-06-29.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-01.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-02.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-03.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-04.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-05.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-06.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-07.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-08.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-09.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-10.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-11.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-12.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-13.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-14.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-15.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-16.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-17.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-18.pcap',
#  'pcaps\\Lumiman_Bulb900\\2019-07-19.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-06-29.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-01.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-02.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-03.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-04.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-05.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-06.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-07.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-08.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-09.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-10.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-11.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-12.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-13.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-14.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-15.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-16.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-17.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-18.pcap',
#  'pcaps\\Lumiman_SmartPlug\\2019-07-19.pcap',
#  'pcaps\\Minger_LightStrip\\2019-06-29.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-01.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-02.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-03.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-04.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-05.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-06.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-07.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-08.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-09.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-10.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-11.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-12.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-13.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-14.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-15.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-16.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-17.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-18.pcap',
#  'pcaps\\Minger_LightStrip\\2019-07-19.pcap',
#  'pcaps\\Ocean_Radio\\2019-06-29.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-01.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-02.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-03.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-04.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-05.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-06.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-07.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-08.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-09.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-10.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-11.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-12.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-13.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-14.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-15.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-16.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-17.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-18.pcap',
#  'pcaps\\Ocean_Radio\\2019-07-19.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-06-29.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-01.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-02.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-03.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-04.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-05.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-06.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-07.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-08.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-09.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-10.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-11.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-12.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-13.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-14.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-15.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-16.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-17.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-18.pcap',
#  'pcaps\\oossxx_SmartPlug\\2019-07-19.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-06-29.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-01.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-02.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-03.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-04.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-05.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-06.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-07.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-08.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-09.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-10.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-11.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-12.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-13.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-14.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-15.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-16.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-17.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-18.pcap',
#  'pcaps\\Renpho_SmartPlug\\2019-07-19.pcap',
#  'pcaps\\Ring_Doorbell\\2019-06-29.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-01.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-02.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-03.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-04.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-05.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-06.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-07.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-08.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-09.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-10.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-11.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-12.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-13.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-14.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-15.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-16.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-17.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-18.pcap',
#  'pcaps\\Ring_Doorbell\\2019-07-19.pcap',
#  'pcaps\\Smart_Lamp\\2019-06-29.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-01.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-02.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-03.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-04.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-05.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-06.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-07.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-08.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-09.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-10.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-11.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-12.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-13.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-14.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-15.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-16.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-17.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-18.pcap',
#  'pcaps\\Smart_Lamp\\2019-07-19.pcap',
#  'pcaps\\Smart_LightStrip\\2019-06-29.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-01.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-02.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-03.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-04.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-05.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-06.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-07.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-08.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-09.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-10.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-11.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-12.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-13.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-14.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-15.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-16.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-17.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-18.pcap',
#  'pcaps\\Smart_LightStrip\\2019-07-19.pcap',
#  'pcaps\\Tenvis_Cam\\2019-06-29.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-01.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-02.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-03.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-04.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-05.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-06.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-07.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-08.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-09.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-10.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-11.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-12.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-13.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-14.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-15.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-16.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-17.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-18.pcap',
#  'pcaps\\Tenvis_Cam\\2019-07-19.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-06-29.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-01.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-02.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-03.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-04.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-05.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-06.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-07.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-08.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-09.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-10.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-11.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-12.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-13.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-14.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-15.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-16.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-17.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-18.pcap',
#  'pcaps\\tp-link_LightBulb\\2019-07-19.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-06-29.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-01.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-02.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-03.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-04.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-05.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-06.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-07.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-08.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-09.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-10.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-11.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-12.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-13.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-14.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-15.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-16.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-17.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-18.pcap',
#  'pcaps\\tp-link_SmartPlug\\2019-07-19.pcap',
#  'pcaps\\Wans_Cam\\2019-06-29.pcap',
#  'pcaps\\Wans_Cam\\2019-07-01.pcap',
#  'pcaps\\Wans_Cam\\2019-07-02.pcap',
#  'pcaps\\Wans_Cam\\2019-07-03.pcap',
#  'pcaps\\Wans_Cam\\2019-07-04.pcap',
#  'pcaps\\Wans_Cam\\2019-07-05.pcap',
#  'pcaps\\Wans_Cam\\2019-07-06.pcap',
#  'pcaps\\Wans_Cam\\2019-07-07.pcap',
#  'pcaps\\Wans_Cam\\2019-07-08.pcap',
#  'pcaps\\Wans_Cam\\2019-07-09.pcap',
#  'pcaps\\Wans_Cam\\2019-07-10.pcap',
#  'pcaps\\Wans_Cam\\2019-07-11.pcap',
#  'pcaps\\Wans_Cam\\2019-07-12.pcap',
#  'pcaps\\Wans_Cam\\2019-07-13.pcap',
#  'pcaps\\Wans_Cam\\2019-07-14.pcap',
#  'pcaps\\Wans_Cam\\2019-07-15.pcap',
#  'pcaps\\Wans_Cam\\2019-07-16.pcap',
#  'pcaps\\Wans_Cam\\2019-07-17.pcap',
#  'pcaps\\Wans_Cam\\2019-07-18.pcap',
#  'pcaps\\Wans_Cam\\2019-07-19.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-06-29.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-01.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-02.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-03.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-04.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-05.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-06.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-07.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-08.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-09.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-10.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-11.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-12.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-13.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-14.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-15.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-16.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-17.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-18.pcap',
#  'pcaps\\Wemo_SmartPlug\\2019-07-19.pcap']

# %%
"""
essiz=[]
new=[]
for i in files_add:
    temp=i[:-16]
    if temp not in essiz:
        essiz.append(temp)
        new.append(i)
        print(temp)"""
# Out:
# '\nessiz=[]\nnew=[]\nfor i in files_add:\n    temp=i[:-16]\n    if temp not in essiz:\n        essiz.append(temp)\n        new.append(i)\n        print(temp)'

# %%
MAC_list={":\\xe8\\x13ua\\x00\\x00'":['2c:3a:e8:13:75:61', 'oossxx_SmartPlug'],
 "b'$\\xf5\\xa2\\xff\\xad\\x97\\x00\\x00'":['24:f5:a2:ff:ad:97', 'Wemo_SmartPlug'],
 "b'(\\xad>r\\xbd~\\x00\\x00'":['28:ad:3e:72:bd:7e', 'Wans_Cam'],
 "b'4\\x03\\xde\\x14\\xdc;\\x00\\x00'":['34:03:de:14:dc:3b', 'Ring_Doorbell'],
 "b'P\\xc7\\xbf\\xeb\\xec\\xc4\\x00\\x00'":[ '50:c7:bf:eb:ec:c4', 'tp-link_LightBulb'],
 "b'\\x00\\xe0Lq\\xb6\\xb6\\x00\\x00'":[ '00:e0:4c:71:b6:b6', 'Minger_LightStrip'],
 "b'\\x0c\\x80ced\\xde\\x00\\x00'": ['0c:80:63:65:64:de', 'tp-link_SmartPlug'],
 "b'\\x14k\\x9c\\x85\\x8a\\xfe\\x00\\x00'":[ '14:6b:9c:85:8a:fe', 'Tenvis_Cam'],
 "b'\\x84 \\x96\\x90C\\xe6\\x00\\x00'":[ '84:20:96:90:43:e6', 'itTiot_Cam'],
 "b'\\x84\\r\\x8e@\\x04T\\x00\\x00'": ['84:0d:8e:40:04:54', 'Lumiman_SmartPlug'] ,
 "b'\\x84\\r\\x8e\\x80b\\x9a\\x00\\x00'":['84:0d:8e:80:62:9a', 'Smart_LightStrip'],
 "b'\\x84\\xf3\\xeb<\\x9eO\\x00\\x00'":[ '84:f3:eb:3c:9e:4f', 'LaCrosse_AlarmClock'],
 "b'\\x84\\xf3\\xeb\\x18\\x91\\xdd\\x00\\x00'":[ '84:f3:eb:18:91:dd', 'Goumia_Coffemaker'],
 "b'\\x84\\xf3\\xebwH\\x1f\\x00\\x00'":['84:f3:eb:77:48:1f', 'Gosuna_LightBulb'],
 "b'\\x88?J\\xf5\\xde\\xd0\\x00\\x00'":['88:3f:4a:f5:de:d0', 'Chime_Doorbell'],
 "b'\\xb2\\xc5TBy\\xf2\\x00\\x00'":['b2:c5:54:42:79:f2', 'D-Link_Cam936L'],
 "b'\\xbc\\xdd\\xc2\\xe1%)\\x00\\x00'":[ 'bc:dd:c2:e1:25:29', 'Smart_Lamp'],
 'b\'\\xdcO"\\x1b/\\xad\\x00\\x00\'':['dc:4f:22:1b:2f:ad', 'Lumiman_Bulb600'],
 "b'\\xec=\\xfdZ\\xbay\\x00\\x00'":[ 'ec:3d:fd:5a:ba:79', 'Ocean_Radio'],
 "b'`8\\xe0\\x12\\x83\\x8a\\x00\\x00'":["UNK","UNK"],
 "b'`\\x01\\x94\\xa7\\xc9\\xfd\\x00\\x00'": ['60:01:94:a7:c9:fd', 'Renpho_SmartPlug'],
 "b'`\\x01\\x94\\xb6\\x1b)\\x00\\x00'":[ '60:01:94:b6:1b:29', 'Gosuna_Socket'],
 "b'`\\x01\\x94n?p\\x00\\x00'":['60:01:94:6e:3f:70', 'Lumiman_Bulb900']}

# %%
def flag_fixer(file):

    IP_flags = {'0': 1, '<Flag 0 ()>': 2, '<Flag 2 (DF)>': 3, '<Flag 1 (MF)>': 4,'<Flag 3 (MF+DF)>':5,
     '<Flag 4 (evil)>':6,
     '<Flag 5 (MF+evil)>':7,
     '<Flag 6 (DF+evil)>':8,
     '<Flag 7 (MF+DF+evil)>':9,
     '<Flag 3 (MF+DF)>':10,
     '<Flag 4 (evil)>':11,
     '<Flag 5 (MF+evil)>':12,
     '<Flag 6 (DF+evil)>':13,
     '<Flag 7 (MF+DF+evil)>':14,
     '<Flag 3 (MF+DF)>':15,
     '<Flag 4 (evil)>':16,
     '<Flag 5 (MF+evil)>':17,
     '<Flag 6 (DF+evil)>':18,
     '<Flag 7 (MF+DF+evil)>':19,
     '<Flag 3 (MF+DF)>':20,
     '<Flag 4 (evil)>':21,
     '<Flag 5 (MF+evil)>':22,
     '<Flag 6 (DF+evil)>':23,
     '<Flag 7 (MF+DF+evil)>':24,
     '<Flag 3 (MF+DF)>':25,
     '<Flag 4 (evil)>':26,
     '<Flag 5 (MF+evil)>':27,
     '<Flag 6 (DF+evil)>':28,
     '<Flag 7 (MF+DF+evil)>':29,
     '<Flag 3 (MF+DF)>':30,
     '<Flag 4 (evil)>':31,
     '<Flag 5 (MF+evil)>':32,
     '<Flag 6 (DF+evil)>':33,
     '<Flag 7 (MF+DF+evil)>':34,
     '<Flag 3 (MF+DF)>':35,
     '<Flag 4 (evil)>':36,
     '<Flag 5 (MF+evil)>':37,
     '<Flag 6 (DF+evil)>':38,
     '<Flag 7 (MF+DF+evil)>':39,
     '<Flag 3 (MF+DF)>':40,
     '<Flag 4 (evil)>':41,
     '<Flag 5 (MF+evil)>':42,
     '<Flag 6 (DF+evil)>':43,
     '<Flag 7 (MF+DF+evil)>':44}
    TCP_flags = {'0': 1, '<Flag 2 (S)>': 2, '<Flag 18 (SA)>': 3, '<Flag 16 (A)>': 4, '<Flag 24 (PA)>': 5, '<Flag 25 (FPA)>': 6, '<Flag 17 (FA)>': 7, '<Flag 4 (R)>': 8, '<Flag 20 (RA)>': 9, '<Flag 194 (SEC)>': 10, '<Flag 1 (F)>': 11, '<Flag 152 (PAC)>': 12, '<Flag 144 (AC)>': 13,'<Flag 82 (SAE)>':14,'<Flag 49 (FAU)>':15, '<Flag 0 ()>':16,
     '<Flag 10 (SP)>':17,
     '<Flag 100 (RUE)>':18,
     '<Flag 102 (SRUE)>':19,
     '<Flag 103 (FSRUE)>':20,
     '<Flag 104 (PUE)>':21,
     '<Flag 106 (SPUE)>':22,
     '<Flag 108 (RPUE)>':23,
     '<Flag 11 (FSP)>':24,
     '<Flag 110 (SRPUE)>':25,
     '<Flag 111 (FSRPUE)>':26,
     '<Flag 112 (AUE)>':27,
     '<Flag 113 (FAUE)>':28,
     '<Flag 114 (SAUE)>':29,
     '<Flag 116 (RAUE)>':30,
     '<Flag 117 (FRAUE)>':31,
     '<Flag 119 (FSRAUE)>':32,
     '<Flag 121 (FPAUE)>':33,
     '<Flag 123 (FSPAUE)>':34,
     '<Flag 124 (RPAUE)>':35,
     '<Flag 125 (FRPAUE)>':36,
     '<Flag 126 (SRPAUE)>':37,
     '<Flag 127 (FSRPAUE)>':38,
     '<Flag 128 (C)>':39,
     '<Flag 129 (FC)>':40,
     '<Flag 13 (FRP)>':41,
     '<Flag 130 (SC)>':42,
     '<Flag 131 (FSC)>':43,
     '<Flag 133 (FRC)>':44,
     '<Flag 134 (SRC)>':45,
     '<Flag 135 (FSRC)>':46,
     '<Flag 136 (PC)>':47,
     '<Flag 137 (FPC)>':48,
     '<Flag 138 (SPC)>':49,
     '<Flag 139 (FSPC)>':50,
     '<Flag 14 (SRP)>':51,
     '<Flag 140 (RPC)>':52,
     '<Flag 145 (FAC)>':53,
     '<Flag 146 (SAC)>':54,
     '<Flag 147 (FSAC)>':55,
     '<Flag 148 (RAC)>':56,
     '<Flag 150 (SRAC)>':57,
     '<Flag 151 (FSRAC)>':58,
     '<Flag 153 (FPAC)>':59,
     '<Flag 154 (SPAC)>':60,
     '<Flag 155 (FSPAC)>':61,
     '<Flag 156 (RPAC)>':62,
     '<Flag 157 (FRPAC)>':63,
     '<Flag 158 (SRPAC)>':64,
     '<Flag 159 (FSRPAC)>':65,
     '<Flag 160 (UC)>':66,
     '<Flag 162 (SUC)>':67,
     '<Flag 163 (FSUC)>':68,
     '<Flag 164 (RUC)>':69,
     '<Flag 166 (SRUC)>':70,
     '<Flag 169 (FPUC)>':71,
     '<Flag 170 (SPUC)>':72,
     '<Flag 171 (FSPUC)>':73,
     '<Flag 172 (RPUC)>':74,
     '<Flag 174 (SRPUC)>':75,
     '<Flag 176 (AUC)>':76,
     '<Flag 177 (FAUC)>':77,
     '<Flag 179 (FSAUC)>':78,
     '<Flag 180 (RAUC)>':79,
     '<Flag 181 (FRAUC)>':80,
     '<Flag 182 (SRAUC)>':81,
     '<Flag 185 (FPAUC)>':82,
     '<Flag 186 (SPAUC)>':83,
     '<Flag 187 (FSPAUC)>':84,
     '<Flag 188 (RPAUC)>':85,
     '<Flag 190 (SRPAUC)>':86,
     '<Flag 191 (FSRPAUC)>':87,
     '<Flag 195 (FSEC)>':88,
     '<Flag 197 (FREC)>':89,
     '<Flag 199 (FSREC)>':90,
     '<Flag 200 (PEC)>':91,
     '<Flag 201 (FPEC)>':92,
     '<Flag 202 (SPEC)>':93,
     '<Flag 203 (FSPEC)>':94,
     '<Flag 204 (RPEC)>':95,
     '<Flag 205 (FRPEC)>':96,
     '<Flag 206 (SRPEC)>':97,
     '<Flag 207 (FSRPEC)>':98,
     '<Flag 208 (AEC)>':99,
     '<Flag 209 (FAEC)>':100,
     '<Flag 210 (SAEC)>':101,
     '<Flag 212 (RAEC)>':102,
     '<Flag 213 (FRAEC)>':103,
     '<Flag 214 (SRAEC)>':104,
     '<Flag 216 (PAEC)>':105,
     '<Flag 218 (SPAEC)>':106,
     '<Flag 219 (FSPAEC)>':107,
     '<Flag 22 (SRA)>':108,
     '<Flag 220 (RPAEC)>':109,
     '<Flag 222 (SRPAEC)>':110,
     '<Flag 224 (UEC)>':111,
     '<Flag 228 (RUEC)>':112,
     '<Flag 229 (FRUEC)>':113,
     '<Flag 23 (FSRA)>':114,
     '<Flag 232 (PUEC)>':115,
     '<Flag 233 (FPUEC)>':116,
     '<Flag 234 (SPUEC)>':117,
     '<Flag 236 (RPUEC)>':118,
     '<Flag 237 (FRPUEC)>':119,
     '<Flag 238 (SRPUEC)>':120,
     '<Flag 240 (AUEC)>':121,
     '<Flag 241 (FAUEC)>':122,
     '<Flag 242 (SAUEC)>':123,
     '<Flag 244 (RAUEC)>':124,
     '<Flag 246 (SRAUEC)>':125,
     '<Flag 248 (PAUEC)>':126,
     '<Flag 249 (FPAUEC)>':127,
     '<Flag 251 (FSPAUEC)>':128,
     '<Flag 252 (RPAUEC)>':129,
     '<Flag 253 (FRPAUEC)>':130,
     '<Flag 254 (SRPAUEC)>':131,
     '<Flag 255 (FSRPAUEC)>':132,
     '<Flag 256 (N)>':133,
     '<Flag 257 (FN)>':134,
     '<Flag 258 (SN)>':135,
     '<Flag 259 (FSN)>':136,
     '<Flag 26 (SPA)>':137,
     '<Flag 260 (RN)>':138,
     '<Flag 261 (FRN)>':139,
     '<Flag 262 (SRN)>':140,
     '<Flag 263 (FSRN)>':141,
     '<Flag 264 (PN)>':142,
     '<Flag 267 (FSPN)>':143,
     '<Flag 268 (RPN)>':144,
     '<Flag 270 (SRPN)>':145,
     '<Flag 272 (AN)>':146,
     '<Flag 273 (FAN)>':147,
     '<Flag 274 (SAN)>':148,
     '<Flag 275 (FSAN)>':149,
     '<Flag 276 (RAN)>':150,
     '<Flag 278 (SRAN)>':151,
     '<Flag 28 (RPA)>':152,
     '<Flag 280 (PAN)>':153,
     '<Flag 281 (FPAN)>':154,
     '<Flag 282 (SPAN)>':155,
     '<Flag 283 (FSPAN)>':156,
     '<Flag 285 (FRPAN)>':157,
     '<Flag 286 (SRPAN)>':158,
     '<Flag 287 (FSRPAN)>':159,
     '<Flag 288 (UN)>':160,
     '<Flag 29 (FRPA)>':161,
     '<Flag 291 (FSUN)>':162,
     '<Flag 292 (RUN)>':163,
     '<Flag 293 (FRUN)>':164,
     '<Flag 296 (PUN)>':165,
     '<Flag 297 (FPUN)>':166,
     '<Flag 298 (SPUN)>':167,
     '<Flag 3 (FS)>':168,
     '<Flag 30 (SRPA)>':169,
     '<Flag 301 (FRPUN)>':170,
     '<Flag 302 (SRPUN)>':171,
     '<Flag 306 (SAUN)>':172,
     '<Flag 307 (FSAUN)>':173,
     '<Flag 308 (RAUN)>':174,
     '<Flag 309 (FRAUN)>':175,
     '<Flag 31 (FSRPA)>':176,
     '<Flag 311 (FSRAUN)>':177,
     '<Flag 312 (PAUN)>':178,
     '<Flag 313 (FPAUN)>':179,
     '<Flag 314 (SPAUN)>':180,
     '<Flag 315 (FSPAUN)>':181,
     '<Flag 316 (RPAUN)>':182,
     '<Flag 318 (SRPAUN)>':183,
     '<Flag 32 (U)>':184,
     '<Flag 323 (FSEN)>':185,
     '<Flag 324 (REN)>':186,
     '<Flag 325 (FREN)>':187,
     '<Flag 326 (SREN)>':188,
     '<Flag 329 (FPEN)>':189,
     '<Flag 33 (FU)>':190,
     '<Flag 330 (SPEN)>':191,
     '<Flag 332 (RPEN)>':192,
     '<Flag 333 (FRPEN)>':193,
     '<Flag 335 (FSRPEN)>':194,
     '<Flag 336 (AEN)>':195,
     '<Flag 338 (SAEN)>':196,
     '<Flag 339 (FSAEN)>':197,
     '<Flag 34 (SU)>':198,
     '<Flag 340 (RAEN)>':199,
     '<Flag 341 (FRAEN)>':200,
     '<Flag 342 (SRAEN)>':201,
     '<Flag 343 (FSRAEN)>':202,
     '<Flag 344 (PAEN)>':203,
     '<Flag 347 (FSPAEN)>':204,
     '<Flag 348 (RPAEN)>':205,
     '<Flag 349 (FRPAEN)>':206,
     '<Flag 350 (SRPAEN)>':207,
     '<Flag 351 (FSRPAEN)>':208,
     '<Flag 352 (UEN)>':209,
     '<Flag 353 (FUEN)>':210,
     '<Flag 354 (SUEN)>':211,
     '<Flag 355 (FSUEN)>':212,
     '<Flag 356 (RUEN)>':213,
     '<Flag 357 (FRUEN)>':214,
     '<Flag 358 (SRUEN)>':215,
     '<Flag 359 (FSRUEN)>':216,
     '<Flag 36 (RU)>':217,
     '<Flag 361 (FPUEN)>':218,
     '<Flag 365 (FRPUEN)>':219,
     '<Flag 366 (SRPUEN)>':220,
     '<Flag 368 (AUEN)>':221,
     '<Flag 369 (FAUEN)>':222,
     '<Flag 37 (FRU)>':223,
     '<Flag 370 (SAUEN)>':224,
     '<Flag 372 (RAUEN)>':225,
     '<Flag 374 (SRAUEN)>':226,
     '<Flag 376 (PAUEN)>':227,
     '<Flag 377 (FPAUEN)>':228,
     '<Flag 378 (SPAUEN)>':229,
     '<Flag 379 (FSPAUEN)>':230,
     '<Flag 38 (SRU)>':231,
     '<Flag 380 (RPAUEN)>':232,
     '<Flag 383 (FSRPAUEN)>':233,
     '<Flag 384 (CN)>':234,
     '<Flag 385 (FCN)>':235,
     '<Flag 389 (FRCN)>':236,
     '<Flag 390 (SRCN)>':237,
     '<Flag 391 (FSRCN)>':238,
     '<Flag 392 (PCN)>':239,
     '<Flag 393 (FPCN)>':240,
     '<Flag 394 (SPCN)>':241,
     '<Flag 396 (RPCN)>':242,
     '<Flag 398 (SRPCN)>':243,
     '<Flag 40 (PU)>':244,
     '<Flag 401 (FACN)>':245,
     '<Flag 402 (SACN)>':246,
     '<Flag 403 (FSACN)>':247,
     '<Flag 404 (RACN)>':248,
     '<Flag 405 (FRACN)>':249,
     '<Flag 406 (SRACN)>':250,
     '<Flag 408 (PACN)>':251,
     '<Flag 409 (FPACN)>':252,
     '<Flag 41 (FPU)>':253,
     '<Flag 410 (SPACN)>':254,
     '<Flag 411 (FSPACN)>':255,
     '<Flag 412 (RPACN)>':256,
     '<Flag 413 (FRPACN)>':257,
     '<Flag 415 (FSRPACN)>':258,
     '<Flag 418 (SUCN)>':259,
     '<Flag 419 (FSUCN)>':260,
     '<Flag 42 (SPU)>':261,
     '<Flag 420 (RUCN)>':262,
     '<Flag 421 (FRUCN)>':263,
     '<Flag 422 (SRUCN)>':264,
     '<Flag 424 (PUCN)>':265,
     '<Flag 426 (SPUCN)>':266,
     '<Flag 427 (FSPUCN)>':267,
     '<Flag 43 (FSPU)>':268,
     '<Flag 433 (FAUCN)>':269,
     '<Flag 436 (RAUCN)>':270,
     '<Flag 437 (FRAUCN)>':271,
     '<Flag 438 (SRAUCN)>':272,
     '<Flag 44 (RPU)>':273,
     '<Flag 440 (PAUCN)>':274,
     '<Flag 442 (SPAUCN)>':275,
     '<Flag 444 (RPAUCN)>':276,
     '<Flag 445 (FRPAUCN)>':277,
     '<Flag 446 (SRPAUCN)>':278,
     '<Flag 447 (FSRPAUCN)>':279,
     '<Flag 448 (ECN)>':280,
     '<Flag 449 (FECN)>':281,
     '<Flag 450 (SECN)>':282,
     '<Flag 451 (FSECN)>':283,
     '<Flag 455 (FSRECN)>':284,
     '<Flag 456 (PECN)>':285,
     '<Flag 458 (SPECN)>':286,
     '<Flag 46 (SRPU)>':287,
     '<Flag 463 (FSRPECN)>':288,
     '<Flag 464 (AECN)>':289,
     '<Flag 465 (FAECN)>':290,
     '<Flag 466 (SAECN)>':291,
     '<Flag 467 (FSAECN)>':292,
     '<Flag 468 (RAECN)>':293,
     '<Flag 469 (FRAECN)>':294,
     '<Flag 47 (FSRPU)>':295,
     '<Flag 472 (PAECN)>':296,
     '<Flag 474 (SPAECN)>':297,
     '<Flag 475 (FSPAECN)>':298,
     '<Flag 476 (RPAECN)>':299,
     '<Flag 478 (SRPAECN)>':300,
     '<Flag 48 (AU)>':301,
     '<Flag 482 (SUECN)>':302,
     '<Flag 483 (FSUECN)>':303,
     '<Flag 484 (RUECN)>':304,
     '<Flag 485 (FRUECN)>':305,
     '<Flag 489 (FPUECN)>':306,
     '<Flag 491 (FSPUECN)>':307,
     '<Flag 492 (RPUECN)>':308,
     '<Flag 493 (FRPUECN)>':309,
     '<Flag 495 (FSRPUECN)>':310,
     '<Flag 497 (FAUECN)>':311,
     '<Flag 498 (SAUECN)>':312,
     '<Flag 5 (FR)>':313,
     '<Flag 50 (SAU)>':314,
     '<Flag 502 (SRAUECN)>':315,
     '<Flag 503 (FSRAUECN)>':316,
     '<Flag 505 (FPAUECN)>':317,
     '<Flag 507 (FSPAUECN)>':318,
     '<Flag 508 (RPAUECN)>':319,
     '<Flag 51 (FSAU)>':320,
     '<Flag 510 (SRPAUECN)>':321,
     '<Flag 511 (FSRPAUECN)>':322,
     '<Flag 52 (RAU)>':323,
     '<Flag 55 (FSRAU)>':324,
     '<Flag 56 (PAU)>':325,
     '<Flag 57 (FPAU)>':326,
     '<Flag 58 (SPAU)>':327,
     '<Flag 59 (FSPAU)>':328,
     '<Flag 6 (SR)>':329,
     '<Flag 61 (FRPAU)>':330,
     '<Flag 62 (SRPAU)>':331,
     '<Flag 66 (SE)>':332,
     '<Flag 67 (FSE)>':333,
     '<Flag 68 (RE)>':334,
     '<Flag 7 (FSR)>':335,
     '<Flag 72 (PE)>':336,
     '<Flag 73 (FPE)>':337,
     '<Flag 74 (SPE)>':338,
     '<Flag 75 (FSPE)>':339,
     '<Flag 76 (RPE)>':340,
     '<Flag 77 (FRPE)>':341,
     '<Flag 79 (FSRPE)>':342,
     '<Flag 8 (P)>':343,
     '<Flag 80 (AE)>':344,
     '<Flag 81 (FAE)>':345,
     '<Flag 83 (FSAE)>':346,
     '<Flag 84 (RAE)>':347,
     '<Flag 85 (FRAE)>':348,
     '<Flag 86 (SRAE)>':349,
     '<Flag 87 (FSRAE)>':350,
     '<Flag 88 (PAE)>':351,
     '<Flag 89 (FPAE)>':352,
     '<Flag 90 (SPAE)>':353,
     '<Flag 92 (RPAE)>':354,
     '<Flag 93 (FRPAE)>':355,
     '<Flag 94 (SRPAE)>':356,
     '<Flag 95 (FSRPAE)>':357,
     '<Flag 96 (UE)>':358,
     '<Flag 98 (SUE)>':359,
     '<Flag 99 (FSUE)>':360}
    BOOTP_flags = {'0': 1, '<Flag 0 ()>': 2, '<Flag 32768 (B)>': 3, 0: 1}
    Protocol = {'EAPOL': 1, 'DHCP': 2, 'DNS': 3, 'TCP': 4, 'HTTP': 5, 'ICMP': 6, 'MDNS': 7, 'IGMPv3': 8, 'SSDP': 9, 'NTP': 10, 'HTTP/XML': 11, 'UDP': 12, 'SSLv2': 13, 'TLSv1': 14, 'ADwin Config': 15, 'TLSv1.2': 16, 'ICMPv6': 17, 'HTTP/JSON': 18, 'XID': 19, 'TFTP': 20, 'NXP 802.15.4 SNIFFER': 21, 'IGMPv2': 22, 'A21': 23, 'STUN': 24, 'Gearman': 25, '? KNXnet/IP': 26, 'UDPENCAP': 27, 'ESP': 28, 'SSL': 29, 'NBNS': 30, 'SIP': 31, 'BROWSER': 32, 'SABP': 33, 'ISAKMP': 34, 'CLASSIC-STUN': 35, 'Omni-Path': 36, 'XMPP/XML': 37, 'ULP': 38, 'TFP over TCP': 39, 'AX4000': 40, 'MIH': 41, 'DHCPv6': 42, 'TDLS': 43, 'RTMP': 44, 'TCPCL': 45, 'IPA': 46, 'GQUIC': 47, '0x86dd': 48, 'DB-LSP-DISC': 49, 'SSLv3': 50, 'LLMNR': 51, 'FB_ZERO': 52, 'OCSP': 53, 'IPv4': 54, 'STP': 55, 'SSH': 56, 'TLSv1.1': 57, 'KINK': 58, 'MANOLITO': 59, 'PKTC': 60, 'TELNET': 61, 'RTSP': 62, 'HCrt': 63, 'MPTCP': 64, 'S101': 65, 'IRC': 66, 'AJP13': 67, 'PMPROXY': 68, 'PNIO': 69, 'AMS': 70, 'ECATF': 71, 'LLC': 72, 'TZSP': 73,'RSIP':74,'SSHv2':75
    ,'DIAMETER':76
    ,'BFD Control':77
    ,'ASAP':78
    ,'DISTCC':79 
    ,'DISTCC ':79       
    ,'LISP':80
    ,'WOW':81
    ,'DTLSv1.0':82
    ,'SNMP':83
    ,'SMB2':84
    ,'SMB':85
    ,'NBSS':86
    ,'UDT':87,'HiQnet':88
    ,'POWERLINK/UDP':89
    ,'RTP':90
    ,'WebSocket':91
    ,'NAT-PMP':92
    ,'RTCP':93,'Syslog':94
    ,'Portmap':95
    ,'OpenVPN':96
    ,'BJNP':97
    ,'RIPv1':98
    ,'MAC-Telnet':99
    ,'ECHO':100
    ,'ASF':101
    ,'DAYTIME':102
    ,'SRVLOC':103
    ,'KRB4':104
    ,'CAPWAP-Control':105
    ,'XDMCP':106
    ,'Chargen':107
    ,'RADIUS':108
    ,'L2TP':109
    ,'DCERPC':110
    ,'KPASSWD':111
    ,'H264':112
    ,'FTP':113
    ,'FTP-DATA':114
    ,'ENIP':115
    ,'RIPv2':116
    ,'ICP':117,
    "BACnet-APDU":118,
    "IAX2":119,
    "RX":120,
    "HTTP2":121,
    "SIP/SDP":122,
    "TIME":123,
    "Elasticsearch":124,
    "RSL":125,
    "TPCP":126,
     "IPv6":  127,"ARP":  128 }

    df=pd.read_csv(file)
    IP_flags
    
    df["IP_flags"]=df["IP_flags"].map(IP_flags.get)
    df["TCP_flags"]=df["TCP_flags"].map(TCP_flags.get)
    df["BOOTP_flags"]=df["BOOTP_flags"].map(BOOTP_flags.get)
    df["Protocol"]=df["Protocol"].map(Protocol.get)
    
    #df=df.replace({"IP_flags": IP_flags})
    #df=df.replace({"TCP_flags": TCP_flags})
    #df=df.replace({"BOOTP_flags": BOOTP_flags})
    #df=df.replace({"Protocol": Protocol})
    #df=df.replace({"Label": label})
    df.to_csv(file,index=None)

# %% [markdown]
# # PCAP2CSV

# %%
from scapy.all import*

# %%
import math
import pandas as pd
import os
import numpy as np

# %%
def folder(f_name): #this function creates a folder.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
def shannon(data):
    LOG_BASE = 2
   # We determine the frequency of each byte
   # in the dataset and if this frequency is not null we use it for the
   # entropy calculation
    dataSize = len(data)
    ent = 0.0
    freq={} 
    for c in data:
        if c in freq:
            freq[c] += 1
        else:
            freq[c] = 1
   # to determine if each possible value of a byte is in the list
    for key in freq.keys():
        f = float(freq[key])/dataSize
        if f > 0: # to avoid an error for log(0)
            ent = ent + f * math.log(f, LOG_BASE)
    return -ent

def pre_entropy(payload):
    
    characters=[]
    for i in payload:
            characters.append(i)
    return shannon(characters)

# %%
def port_class(port):
    port_list=[0,53,67,68,80,123,443,1900,5353,49153]# private port list (0-Reserved,53-DNS, 67-BOOTP server, 68-BOOTP client...)
    if port in port_list: #Is the port number in the list?
        return port_list.index(port)+1 # return the port's index number in the list (actually with index+1)
    elif 0 <= port <= 1023: # return 11 if the port number is in the range 0 :1023
        return 11
    elif  1024 <= port <= 49151 : # return 12 if the port number is in the range 1024:49151
        return 12
    elif 49152 <=port <= 65535 :# return 13 if the port number is in the range 49152:65535
        return 13
    else:# return 0 if no previous conditions are met
        return 0
    
    
def port_1023(port):
    if 0 <= port <= 1023:
        return port
    elif  1024 <= port <= 49151 :
        return 2
    elif 49152 <=port <= 65535 :
        return 3
    else:
        return 0

# %%
header="ts,Ether_dst,Ether_src,IP_src,IP_dst,pck_size,Ether_type,LLC_dsap,LLC_ssap,LLC_ctrl,EAPOL_version,EAPOL_type,EAPOL_len,IP_version,IP_ihl,IP_tos,IP_len,IP_flags,IP_Z,IP_MF,IP_id,IP_chksum,IP_DF,IP_frag,IP_ttl,IP_proto,IP_options,ICMP_type,ICMP_code,ICMP_chksum,ICMP_id,ICMP_seq,ICMP_ts_ori,ICMP_ts_rx,ICMP_ts_tx,ICMP_ptr,ICMP_reserved,ICMP_length,ICMP_nexthopmtu,ICMP_unused,TCP_seq,TCP_ack,TCP_dataofs,TCP_reserved,TCP_flags,TCP_FIN,TCP_SYN,TCP_RST,TCP_PSH,TCP_ACK,TCP_URG,TCP_ECE,TCP_CWR,TCP_window,TCP_chksum,TCP_urgptr,TCP_options,UDP_len,UDP_chksum,DHCP_options,BOOTP_op,BOOTP_htype,BOOTP_hlen,BOOTP_hops,BOOTP_xid,BOOTP_secs,BOOTP_flags,BOOTP_sname,BOOTP_file,BOOTP_options,DNS_length,DNS_id,DNS_qr,DNS_opcode,DNS_aa,DNS_tc,DNS_rd,DNS_ra,DNS_z,DNS_ad,DNS_cd,DNS_rcode,DNS_qdcount,DNS_ancount,DNS_nscount,DNS_arcount,sport_class,dport_class,sport23,dport23,sport_bare,dport_bare,TCP_sport,TCP_dport,UDP_sport,UDP_dport,payload_bytes,entropy,Label\n"

#header="pck_size,Ether_type,LLC_dsap,LLC_ssap,LLC_ctrl,EAPOL_version,EAPOL_type,EAPOL_len,IP_version,IP_ihl,IP_tos,IP_len,IP_flags,IP_frag,IP_ttl,IP_proto,IP_options,IP_add_count,ICMP_type,ICMP_code,ICMP_seq,ICMP_ts_ori,ICMP_ts_rx,ICMP_ts_tx,ICMP_gw,ICMP_ptr,ICMP_reserved,ICMP_length,ICMP_nexthopmtu,ICMP_unused,TCP_dataofs,TCP_reserved,TCP_flags,TCP_window,TCP_urgptr,UDP_len,BOOTP_op,BOOTP_htype,BOOTP_hlen,BOOTP_hops,BOOTP_secs,BOOTP_flags,DNS_length,DNS_qr,DNS_opcode,DNS_aa,DNS_tc,DNS_rd,DNS_ra,DNS_z,DNS_ad,DNS_cd,DNS_rcode,DNS_qdcount,DNS_ancount,DNS_nscount,DNS_arcount,sport,dport,entropy,Label,MAC\n"

# %%
#flags
#TCP
FIN = 0x01
SYN = 0x02
RST = 0x04
PSH = 0x08
ACK = 0x10
URG = 0x20
ECE = 0x40
CWR = 0x80
#IP
Z = 0x00
MF= 0x01
DF= 0x02

# %% [markdown]
# # Individual paket pased faetures

# %%
def pcap_parser(oldname):
    piece_size=50000
    new_name=oldname.replace(".pcap","_smaller.pcap")
    command='C:/\"Program Files\"/Wireshark/editcap.exe -c '+str(piece_size)+" \""+oldname+"\" "+new_name   
    os.system(command)
    parsed=find_the_way("./",new_name[6:-5])
    return parsed,new_name[6:-5]

# %%
def merged_csv(name,keyword):
    for merger in ["_FE.csv","_WS.csv"]:
        merged_name=f"{name[:-4]}{merger}"
        csv_files=find_the_way("./",keyword,merger)
        df=pd.read_csv(csv_files[0])
        col_names=list(df.columns)

        empty = pd.DataFrame(columns=col_names)
        empty.to_csv(merged_name, mode="w", index=False)#,header=False)


        for j in csv_files:

            df=pd.read_csv(j)
            #print("name and shape of dataframe :",i,df.shape)
            df.to_csv(merged_name, mode="a", index=False,header=False)


            os.remove(j)
            try:
                os.remove(j.replace("_FE.csv",".pcap"))
            except:pass

            #print("\n\n\nname and shape of dataframe :",name,df.shape)

# %%
outputfolder="FE"
folder(outputfolder)




for sayac,i in enumerate (files_add):
    print(f"{sayac+1}/{len(files_add)}-{i}")
    boyut=os.path.getsize(i)
    label_count=0
    if boyut >100000000:
        file_list,keyword=pcap_parser(i)

    else:
        file_list=[i]    
    for isim in file_list:
    
        filename=isim.replace(".pcap","_FE.csv")
        ths = open(filename, "w")
        ths.write(header)  
 
    
    
        pkt = rdpcap(isim)
        for j in tqdm(pkt):
            
            if j.haslayer(ARP):
                continue
            else:
                ts=float(j.time)
                try:pck_size=j.len
                except:pck_size=0
                if j.haslayer(Ether):


                    Ether_dst=j[Ether].dst#Ether_adresses.index(j[Ether].dst)+1
                    Ether_src=j[Ether].src#Ether_adj[Ether].dstresses.index(j[Ether].src)+1


                    Ether_type=j[Ether].type
                else:
                    Ether_dst=0
                    Ether_src=0
                    Ether_type=0


                if j.haslayer(ARP):
                    ARP_hwtype=j[ARP].hwtype
                    ARP_ptype=j[ARP].ptype
                    ARP_hwlen=j[ARP].hwlen
                    ARP_plen=j[ARP].plen
                    ARP_op=j[ARP].op


                    ARP_hwsrc=j[ARP].hwsrc
                    ARP_psrc=j[ARP].psrc
                    ARP_hwdst=j[ARP].hwdst
                    ARP_pdst=j[ARP].pdst




                    ARP_hwsrc=j[ARP].hwsrc#Ether_adresses.index(j[ARP].hwsrc)+1
                    ARP_psrc=j[ARP].psrc#IP_adresses.index(j[ARP].psrc)+1
                    ARP_hwdst=j[ARP].hwdst#Ether_adresses.index(j[ARP].hwdst)+1
                    ARP_pdst=j[ARP].pdst#IP_adresses.index(j[ARP].pdst)+1


                else:
                    ARP_hwtype=0
                    ARP_ptype=0
                    ARP_hwlen=0
                    ARP_plen=0
                    ARP_op=0
                    ARP_hwsrc=0
                    ARP_psrc=0
                    ARP_hwdst=0
                    ARP_pdst=0            


                if j.haslayer(LLC):
                    LLC_dsap=j[LLC].dsap
                    LLC_ssap=j[LLC].ssap
                    LLC_ctrl=j[LLC].ctrl
                else:
                    LLC_dsap=0
                    LLC_ssap=0
                    LLC_ctrl=0            



                if j.haslayer(EAPOL):
                    EAPOL_version=j[EAPOL].version
                    EAPOL_type=j[EAPOL].type
                    EAPOL_len=j[EAPOL].len

                else:
                    EAPOL_version=0
                    EAPOL_type=0
                    EAPOL_len=0            


                if j.haslayer(IP):

                    IP_Z = 0
                    IP_MF= 0
                    IP_DF= 0

                    IP_version=j[IP].version
                    IP_ihl=j[IP].ihl
                    IP_tos=j[IP].tos
                    IP_len=j[IP].len
                    IP_id=j[IP].id
                    IP_flags=j[IP].flags

                    IP_frag=j[IP].frag
                    IP_ttl=j[IP].ttl
                    IP_proto=j[IP].proto
                    IP_chksum=j[IP].chksum


                    #if j[IP].options!=0:
                    IP_options=j[IP].options
                    if "IPOption_Router_Alert"   in str(IP_options):
                        IP_options=1
                    else:IP_options=0



                    #if IP_flags not in ipf: ipf.append(IP_flags)

                    if IP_flags & Z:IP_Z = 1
                    if IP_flags & MF:IP_MF = 1
                    if IP_flags & DF:IP_DF = 1
                    #if "Flag" in str(IP_flags):
                        #IP_flags=str(IP_flags)
                        #temp=IP_flags.find("(")
                        #IP_flags=int(IP_flags[6:temp-1])




                    IP_src=j[IP].src#IP_adresses.index(j[IP].src)+1
                    IP_dst=j[IP].dst#IP_adresses.index(j[IP].dst)+1                



                else:
                    IP_Z = 0
                    IP_MF= 0
                    IP_DF= 0

                    IP_version=0
                    IP_ihl=0
                    IP_tos=0
                    IP_len=0
                    IP_id=0
                    IP_flags=0
                    IP_frag=0
                    IP_ttl=0
                    IP_proto=0
                    IP_chksum=0
                    IP_src=0
                    IP_dst=0
                    IP_options=0
                    IP_add_count=0            

                if j.haslayer(ICMP):
                    ICMP_type=j[ICMP].type
                    ICMP_code=j[ICMP].code
                    ICMP_chksum=j[ICMP].chksum
                    ICMP_id=j[ICMP].id
                    ICMP_seq=j[ICMP].seq
                    ICMP_ts_ori=j[ICMP].ts_ori
                    ICMP_ts_rx=j[ICMP].ts_rx
                    ICMP_ts_tx=j[ICMP].ts_tx
                    ICMP_gw=j[ICMP].gw
                    ICMP_ptr=j[ICMP].ptr
                    ICMP_reserved=j[ICMP].reserved
                    ICMP_length=j[ICMP].length
                    ICMP_addr_mask=j[ICMP].addr_mask
                    ICMP_nexthopmtu=j[ICMP].nexthopmtu
                    ICMP_unused=j[ICMP].unused
                else:
                    ICMP_type=0
                    ICMP_code=0
                    ICMP_chksum=0
                    ICMP_id=0
                    ICMP_seq=0
                    ICMP_ts_ori=0
                    ICMP_ts_rx=0
                    ICMP_ts_tx=0
                    ICMP_gw=0
                    ICMP_ptr=0
                    ICMP_reserved=0
                    ICMP_length=0
                    ICMP_addr_mask=0
                    ICMP_nexthopmtu=0
                    ICMP_unused=0




                if j.haslayer(TCP):
                    TCP_FIN = 0
                    TCP_SYN = 0
                    TCP_RST = 0
                    TCP_PSH = 0
                    TCP_ACK = 0
                    TCP_URG = 0
                    TCP_ECE = 0
                    TCP_CWR = 0
                    TCP_sport=j[TCP].sport
                    TCP_dport=j[TCP].dport
                    TCP_seq=j[TCP].seq
                    TCP_ack=j[TCP].ack
                    TCP_dataofs=j[TCP].dataofs
                    TCP_reserved=j[TCP].reserved
                    TCP_flags=j[TCP].flags

                    TCP_window=j[TCP].window
                    TCP_chksum=j[TCP].chksum
                    TCP_urgptr=j[TCP].urgptr
                    TCP_options=j[TCP].options
                    TCP_options= str(TCP_options).replace(",","-")
                    if TCP_options!="0":
                        TCP_options=1
                    else:
                        TCP_options=0




                    #if TCP_flags not in tcpf:
                        #tcpf.append(TCP_flags)
                    #print(TCP_options)
                    if TCP_flags & FIN:TCP_FIN = 1
                    if TCP_flags & SYN:TCP_SYN = 1
                    if TCP_flags & RST:TCP_RST = 1
                    if TCP_flags & PSH:TCP_PSH = 1
                    if TCP_flags & ACK:TCP_ACK = 1
                    if TCP_flags & URG:TCP_URG = 1
                    if TCP_flags & ECE:TCP_ECE = 1
                    if TCP_flags & CWR:TCP_CWR = 1   
                    #print(TCP_flags)
                    #if "Flag" in str(TCP_flags):
                        #TCP_flags=str(TCP_flags)
                        #temp=TCP_flags.find("(")
                        #TCP_flags=int(TCP_flags[6:temp-1])




                else:
                    TCP_sport=0
                    TCP_dport=0
                    TCP_seq=0
                    TCP_ack=0
                    TCP_dataofs=0
                    TCP_reserved=0
                    TCP_flags=0
                    TCP_window=0
                    TCP_chksum=0
                    TCP_urgptr=0
                    TCP_options=0
                    TCP_options=0
                    TCP_FIN = 0
                    TCP_SYN = 0
                    TCP_RST = 0
                    TCP_PSH = 0
                    TCP_ACK = 0
                    TCP_URG = 0
                    TCP_ECE = 0
                    TCP_CWR = 0


                if j.haslayer(UDP):
                    UDP_sport=j[UDP].sport
                    UDP_dport=j[UDP].dport
                    UDP_len=j[UDP].len
                    UDP_chksum=j[UDP].chksum
                else:
                    UDP_sport=0
                    UDP_dport=0
                    UDP_len=0
                    UDP_chksum=0





                if j.haslayer(DHCP):
                    DHCP_options=str(j[DHCP].options)
                    DHCP_options=DHCP_options.replace(",","-")
                    if "message" in DHCP_options:
                        x = DHCP_options.find(")")
                        DHCP_options=int(DHCP_options[x-1])

                else:
                    DHCP_options=0            


                if j.haslayer(BOOTP):
                    BOOTP_op=j[BOOTP].op
                    BOOTP_htype=j[BOOTP].htype
                    BOOTP_hlen=j[BOOTP].hlen
                    BOOTP_hops=j[BOOTP].hops
                    BOOTP_xid=j[BOOTP].xid
                    BOOTP_secs=j[BOOTP].secs
                    BOOTP_flags=j[BOOTP].flags
                    #if "Flag" in str(BOOTP_flags):BOOTP_flags=str(BOOTP_flags)temp=BOOTP_flags.find("(") BOOTP_flags=int(BOOTP_flags[6:temp-1])
                    BOOTP_ciaddr=j[BOOTP].ciaddr
                    BOOTP_yiaddr=j[BOOTP].yiaddr
                    BOOTP_siaddr=j[BOOTP].siaddr
                    BOOTP_giaddr=j[BOOTP].giaddr
                    BOOTP_chaddr=j[BOOTP].chaddr
                    BOOTP_sname=str(j[BOOTP].sname)
                    if BOOTP_sname!="0":
                        BOOTP_sname=1
                    else:
                        BOOTP_sname=0
                    BOOTP_file=str(j[BOOTP].file)
                    if BOOTP_file!="0":
                        BOOTP_file=1
                    else:
                        BOOTP_file=0

                    BOOTP_options=str(j[BOOTP].options)
                    BOOTP_options=BOOTP_options.replace(",","-")
                    if BOOTP_options!="0":
                        BOOTP_options=1
                    else:
                        BOOTP_options=0
                else:
                    BOOTP_op=0
                    BOOTP_htype=0
                    BOOTP_hlen=0
                    BOOTP_hops=0
                    BOOTP_xid=0
                    BOOTP_secs=0
                    BOOTP_flags=0
                    BOOTP_ciaddr=0
                    BOOTP_yiaddr=0
                    BOOTP_siaddr=0
                    BOOTP_giaddr=0
                    BOOTP_chaddr=0
                    BOOTP_sname=0
                    BOOTP_file=0
                    BOOTP_options=0






                if j.haslayer(DNS):
                    DNS_length=j[DNS].length
                    DNS_id=j[DNS].id
                    DNS_qr=j[DNS].qr
                    DNS_opcode=j[DNS].opcode
                    DNS_aa=j[DNS].aa
                    DNS_tc=j[DNS].tc
                    DNS_rd=j[DNS].rd
                    DNS_ra=j[DNS].ra
                    DNS_z=j[DNS].z
                    DNS_ad=j[DNS].ad
                    DNS_cd=j[DNS].cd
                    DNS_rcode=j[DNS].rcode
                    DNS_qdcount=j[DNS].qdcount
                    DNS_ancount=j[DNS].ancount
                    DNS_nscount=j[DNS].nscount
                    DNS_arcount=j[DNS].arcount
                    DNS_qd=str(j[DNS].qd).replace(",","-")
                    if DNS_qd!="0":
                        DNS_qd=1
                    else:
                        DNS_qd=0
                    DNS_an=str(j[DNS].an).replace(",","-")
                    if DNS_an!="0":
                        DNS_an=1
                    else:
                        DNS_an=0
                    DNS_ns=str(j[DNS].ns).replace(",","-")
                    if DNS_ns!="0":
                        DNS_ns=1
                    else:
                        DNS_ns=0
                    DNS_ar=str(j[DNS].ar).replace(",","-")
                    if DNS_ar!="0":
                        DNS_ar=1
                    else:
                        DNS_ar=0
                else:
                    DNS_length=0
                    DNS_id=0
                    DNS_qr=0
                    DNS_opcode=0
                    DNS_aa=0
                    DNS_tc=0
                    DNS_rd=0
                    DNS_ra=0
                    DNS_z=0
                    DNS_ad=0
                    DNS_cd=0
                    DNS_rcode=0
                    DNS_qdcount=0
                    DNS_ancount=0
                    DNS_nscount=0
                    DNS_arcount=0
                    DNS_qd=0
                    DNS_an=0
                    DNS_ns=0
                    DNS_ar=0





                pdata=[]
                if "TCP" in j:            
                    pdata = (j[TCP].payload)
                if "Raw" in j:
                    pdata = (j[Raw].load)
                elif "UDP" in j:            
                    pdata = (j[UDP].payload)
                elif "ICMP" in j:            
                    pdata = (j[ICMP].payload)
                pdata=list(memoryview(bytes(pdata)))            

                if pdata!=[]:
                    entropy=shannon(pdata)        
                else:
                    entropy=0
                payload_bytes=len(pdata)

                sport_class=port_class(TCP_sport+UDP_sport)
                dport_class=port_class(TCP_dport+UDP_dport)
                sport23=port_1023(TCP_sport+UDP_sport)
                dport23=port_1023(TCP_dport+UDP_dport)
                sport_bare=TCP_sport+UDP_sport
                dport_bare=TCP_dport+UDP_dport#port_class(TCP_dport+UDP_dport)


                Mac=str(j.src)          
                #Mac = Mac.replace('\\x',':')
                #Mac=Mac[3:-1]



                line=[ts,
                      Ether_dst,
                Ether_src,
                IP_src,
                IP_dst,
                pck_size,
                Ether_type,
                LLC_dsap,
                LLC_ssap,
                LLC_ctrl,
                EAPOL_version,
                EAPOL_type,
                EAPOL_len,
                IP_version,
                IP_ihl,
                IP_tos,
                IP_len,
                IP_flags,
                IP_Z,
                IP_MF,
                IP_id,
                IP_chksum,
                IP_DF  ,
                IP_frag,
                IP_ttl,
                IP_proto,
                IP_options,
                ICMP_type,
                ICMP_code,
                ICMP_chksum,
                ICMP_id,
                ICMP_seq,
                ICMP_ts_ori,
                ICMP_ts_rx,
                ICMP_ts_tx,
                ICMP_ptr,
                ICMP_reserved,
                ICMP_length,
                #ICMP_addr_mask,
                ICMP_nexthopmtu,
                ICMP_unused,
                TCP_seq,
                TCP_ack,
                TCP_dataofs,
                TCP_reserved,
                TCP_flags,
                TCP_FIN,
                TCP_SYN,
                TCP_RST,
                TCP_PSH,
                TCP_ACK,
                TCP_URG,
                TCP_ECE,
                TCP_CWR   ,
                TCP_window,
                TCP_chksum,
                TCP_urgptr,
                TCP_options,
                UDP_len,
                UDP_chksum,
                DHCP_options,
                BOOTP_op,
                BOOTP_htype,
                BOOTP_hlen,
                BOOTP_hops,
                BOOTP_xid,
                BOOTP_secs,
                BOOTP_flags,
                BOOTP_sname,
                BOOTP_file,
                BOOTP_options,
                DNS_length,
                DNS_id,
                DNS_qr,
                DNS_opcode,
                DNS_aa,
                DNS_tc,
                DNS_rd,
                DNS_ra,
                DNS_z,
                DNS_ad,
                DNS_cd,
                DNS_rcode,
                DNS_qdcount,
                DNS_ancount,
                DNS_nscount,
                DNS_arcount,
                sport_class,
                dport_class,
                sport23,
                dport23,
                sport_bare,
                dport_bare,
                TCP_sport,
                TCP_dport,
                UDP_sport,
                UDP_dport, 
                payload_bytes,
                entropy]

                #print(line)
                line=str(line).replace("[","")
                line=str(line).replace("]","")
                #line=str(line).replace("\',","-")
                line=str(line).replace(", ",",")
                line=str(line).replace("\'","")
                line=str(line).replace("None","0")
                if Mac in MAC_list:
                    Label=MAC_list[Mac][1]
                else:
                    Label=Mac
                ths.write(str(line)+f",{Label}\n")  
                label_count+=1
                #kk=line.split(",")
                #print(len(kk))
                #if len(kk)==112:
                #ths.write(line+"\n")

                #else:print(line)
        name=isim.replace("\\","/")
        output=filename.replace("_FE.csv","_WS.csv")

        if " " not in name:
            command=f"tshark -r {name}  -T fields -e _ws.col.Source -e _ws.col.Destination  -e _ws.col.Protocol    -E header=y -E separator=, -E quote=d -E occurrence=f >{output}"
        else:
            command=f"tshark -r \"{name}\" -T fields -e _ws.col.Source -e _ws.col.Destination  -e _ws.col.Protocol    -E header=y -E separator=, -E quote=d -E occurrence=f >\"{output}\""
        os.system(command)
        ths.close()          
    if len(file_list)>1:
        merged_csv(i,keyword)
# Out:
# 1/440-pcaps\Chime_Doorbell\2019-06-29.pcap
#   0%|                                                                                        | 0/11169 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 11169/11169 [00:04<00:00, 2596.95it/s]
# 2/440-pcaps\Chime_Doorbell\2019-07-01.pcap
#   0%|                                                                                        | 0/10924 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 10924/10924 [00:04<00:00, 2488.34it/s]
# 3/440-pcaps\Chime_Doorbell\2019-07-02.pcap
#   0%|                                                                                        | 0/11828 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  90%|██████████████████████████████████████████████████████████████████▋       | 10652/11828 [00:05<00:00, 1819.48it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 11828/11828 [00:05<00:00, 2073.46it/s]
# 4/440-pcaps\Chime_Doorbell\2019-07-03.pcap
#   0%|                                                                                        | 0/12064 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  77%|█████████████████████████████████████████████████████████▋                 | 9273/12064 [00:04<00:01, 2054.62it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  79%|███████████████████████████████████████████████████████████                | 9495/12064 [00:05<00:01, 2087.68it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 12064/12064 [00:06<00:00, 1931.61it/s]
# 5/440-pcaps\Chime_Doorbell\2019-07-04.pcap
#   0%|                                                                                        | 0/10776 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|████████████████████████████████████████████████████████████████████▋     | 10011/10776 [00:04<00:00, 2103.99it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 10776/10776 [00:05<00:00, 2009.07it/s]
# 6/440-pcaps\Chime_Doorbell\2019-07-05.pcap
#   0%|                                                                                        | 0/11122 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|█████████████████████████████████████████████████████████████████████     | 10381/11122 [00:04<00:00, 2112.62it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#  96%|██████████████████████████████████████████████████████████████████████▉   | 10668/11122 [00:05<00:00, 2330.19it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 11122/11122 [00:05<00:00, 2108.99it/s]
# 7/440-pcaps\Chime_Doorbell\2019-07-06.pcap
#   5%|███▋                                                                        | 529/10846 [00:00<00:05, 1831.61it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 10846/10846 [00:05<00:00, 2060.32it/s]
# 8/440-pcaps\Chime_Doorbell\2019-07-07.pcap
#   0%|                                                                                        | 0/12411 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  75%|████████████████████████████████████████████████████████▏                  | 9308/12411 [00:05<00:01, 2020.50it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 12411/12411 [00:06<00:00, 1859.32it/s]
# 9/440-pcaps\Chime_Doorbell\2019-07-08.pcap
#   0%|                                                                                        | 0/12534 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  82%|████████████████████████████████████████████████████████████▉             | 10328/12534 [00:05<00:01, 1988.64it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 12534/12534 [00:06<00:00, 2064.95it/s]
# 10/440-pcaps\Chime_Doorbell\2019-07-09.pcap
#   0%|                                                                                        | 0/11894 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  84%|██████████████████████████████████████████████████████████████▍           | 10029/11894 [00:04<00:00, 2191.07it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 11894/11894 [00:05<00:00, 2054.71it/s]
# 11/440-pcaps\Chime_Doorbell\2019-07-10.pcap
#   0%|                                                                                        | 0/11688 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  85%|███████████████████████████████████████████████████████████████▋           | 9932/11688 [00:04<00:00, 2130.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 11688/11688 [00:05<00:00, 2032.68it/s]
# 12/440-pcaps\Chime_Doorbell\2019-07-11.pcap
#   0%|                                                                                        | 0/12397 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  85%|███████████████████████████████████████████████████████████████▏          | 10592/12397 [00:05<00:01, 1669.29it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 12397/12397 [00:05<00:00, 2124.10it/s]
# 13/440-pcaps\Chime_Doorbell\2019-07-12.pcap
#   0%|                                                                                        | 0/11831 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  87%|████████████████████████████████████████████████████████████████▎         | 10282/11831 [00:05<00:00, 2229.93it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 11831/11831 [00:05<00:00, 2022.59it/s]
# 14/440-pcaps\Chime_Doorbell\2019-07-13.pcap
#   0%|                                                                                        | 0/11730 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#   2%|█▏                                                                          | 184/11730 [00:00<00:06, 1776.09it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  88%|████████████████████████████████████████████████████████████████▊         | 10266/11730 [00:05<00:00, 2045.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  89%|██████████████████████████████████████████████████████████████████        | 10471/11730 [00:05<00:00, 2021.17it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 11730/11730 [00:05<00:00, 2022.45it/s]
# 15/440-pcaps\Chime_Doorbell\2019-07-14.pcap
#   0%|                                                                                        | 0/11671 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  91%|███████████████████████████████████████████████████████████████████▋      | 10667/11671 [00:05<00:00, 2156.32it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 11671/11671 [00:05<00:00, 2080.61it/s]
# 16/440-pcaps\Chime_Doorbell\2019-07-15.pcap
#   0%|                                                                                        | 0/12712 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  79%|██████████████████████████████████████████████████████████▌               | 10062/12712 [00:05<00:01, 1908.94it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 12712/12712 [00:06<00:00, 1965.40it/s]
# 17/440-pcaps\Chime_Doorbell\2019-07-16.pcap
#   0%|                                                                                        | 0/12822 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  78%|██████████████████████████████████████████████████████████▏                | 9957/12822 [00:04<00:01, 1806.98it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 12822/12822 [00:06<00:00, 1988.67it/s]
# 18/440-pcaps\Chime_Doorbell\2019-07-17.pcap
#   0%|                                                                                        | 0/12450 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  82%|████████████████████████████████████████████████████████████▉             | 10246/12450 [00:05<00:01, 1767.73it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 12450/12450 [00:06<00:00, 2026.39it/s]
# 19/440-pcaps\Chime_Doorbell\2019-07-18.pcap
#   0%|                                                                                        | 0/13333 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  77%|████████████████████████████████████████████████████████▉                 | 10269/13333 [00:05<00:01, 1873.83it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 13333/13333 [00:06<00:00, 1994.03it/s]
# 20/440-pcaps\Chime_Doorbell\2019-07-19.pcap
#   0%|                                                                                        | 0/18530 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  54%|████████████████████████████████████████▎                                 | 10080/18530 [00:04<00:04, 1818.01it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  80%|███████████████████████████████████████████████████████████▋               | 14760/18530 [00:10<00:06, 542.16it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  97%|████████████████████████████████████████████████████████████████████████▉  | 18018/18530 [00:14<00:00, 622.51it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 18530/18530 [00:15<00:00, 1193.16it/s]
# 21/440-pcaps\D-Link_Cam936L\2019-06-29.pcap
#  58%|██████████████████████████████████████████▉                               | 13684/23574 [00:05<00:03, 2560.52it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 23574/23574 [00:09<00:00, 2555.08it/s]
# 22/440-pcaps\D-Link_Cam936L\2019-07-01.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 22999/22999 [00:08<00:00, 2570.58it/s]
# 23/440-pcaps\D-Link_Cam936L\2019-07-02.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 21562/21562 [00:08<00:00, 2499.63it/s]
# 24/440-pcaps\D-Link_Cam936L\2019-07-03.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 23714/23714 [00:09<00:00, 2564.98it/s]
# 25/440-pcaps\D-Link_Cam936L\2019-07-04.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 23480/23480 [00:09<00:00, 2591.73it/s]
# 26/440-pcaps\D-Link_Cam936L\2019-07-05.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 23411/23411 [00:09<00:00, 2597.79it/s]
# 27/440-pcaps\D-Link_Cam936L\2019-07-06.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 23308/23308 [00:09<00:00, 2574.95it/s]
# 28/440-pcaps\D-Link_Cam936L\2019-07-07.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 25859/25859 [00:10<00:00, 2582.45it/s]
# 29/440-pcaps\D-Link_Cam936L\2019-07-08.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 24975/24975 [00:09<00:00, 2524.35it/s]
# 30/440-pcaps\D-Link_Cam936L\2019-07-09.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 24940/24940 [00:10<00:00, 2488.56it/s]
# 31/440-pcaps\D-Link_Cam936L\2019-07-10.pcap
#  90%|██████████████████████████████████████████████████████████████████▍       | 23891/26596 [00:09<00:01, 2181.23it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 26596/26596 [00:11<00:00, 2401.76it/s]
# 32/440-pcaps\D-Link_Cam936L\2019-07-11.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 24940/24940 [00:09<00:00, 2528.79it/s]
# 33/440-pcaps\D-Link_Cam936L\2019-07-12.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 24972/24972 [00:09<00:00, 2515.63it/s]
# 34/440-pcaps\D-Link_Cam936L\2019-07-13.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 24920/24920 [00:10<00:00, 2487.21it/s]
# 35/440-pcaps\D-Link_Cam936L\2019-07-14.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 24956/24956 [00:10<00:00, 2385.72it/s]
# 36/440-pcaps\D-Link_Cam936L\2019-07-15.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 24960/24960 [00:09<00:00, 2511.80it/s]
# 37/440-pcaps\D-Link_Cam936L\2019-07-16.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 24816/24816 [00:10<00:00, 2430.72it/s]
# 38/440-pcaps\D-Link_Cam936L\2019-07-17.pcap
#  91%|███████████████████████████████████████████████████████████████████▎      | 23146/25428 [00:09<00:00, 2813.19it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 25428/25428 [00:10<00:00, 2432.74it/s]
# 39/440-pcaps\D-Link_Cam936L\2019-07-18.pcap
# 100%|██████████████████████████████████████████████████████████████████████████| 25032/25032 [00:09<00:00, 2586.43it/s]
# 40/440-pcaps\D-Link_Cam936L\2019-07-19.pcap
#  88%|█████████████████████████████████████████████████████████████████▍        | 22277/25204 [00:08<00:01, 2524.07it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 25204/25204 [00:10<00:00, 2451.85it/s]
# 41/440-pcaps\Gosuna_LightBulb\2019-06-29.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 109112/109112 [00:43<00:00, 2490.86it/s]
# 42/440-pcaps\Gosuna_LightBulb\2019-07-01.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 110270/110270 [00:44<00:00, 2491.24it/s]
# 43/440-pcaps\Gosuna_LightBulb\2019-07-02.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 101341/101341 [00:43<00:00, 2318.32it/s]
# 44/440-pcaps\Gosuna_LightBulb\2019-07-03.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 113378/113378 [00:59<00:00, 1916.00it/s]
# 45/440-pcaps\Gosuna_LightBulb\2019-07-04.pcap
#   8%|██████▏                                                                   | 9492/113175 [00:03<00:42, 2442.14it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 113175/113175 [00:47<00:00, 2357.88it/s]
# 46/440-pcaps\Gosuna_LightBulb\2019-07-05.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 113743/113743 [00:46<00:00, 2456.46it/s]
# 47/440-pcaps\Gosuna_LightBulb\2019-07-06.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 113043/113043 [00:47<00:00, 2382.56it/s]
# 48/440-pcaps\Gosuna_LightBulb\2019-07-07.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 122977/122977 [00:51<00:00, 2375.05it/s]
# 49/440-pcaps\Gosuna_LightBulb\2019-07-08.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115157/115157 [00:47<00:00, 2437.83it/s]
# 50/440-pcaps\Gosuna_LightBulb\2019-07-09.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115168/115168 [00:50<00:00, 2289.47it/s]
# 51/440-pcaps\Gosuna_LightBulb\2019-07-10.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 114940/114940 [00:52<00:00, 2171.07it/s]
# 52/440-pcaps\Gosuna_LightBulb\2019-07-11.pcap
#  42%|██████████████████████████████▍                                          | 48053/115177 [00:22<00:30, 2166.84it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115177/115177 [00:53<00:00, 2150.77it/s]
# 53/440-pcaps\Gosuna_LightBulb\2019-07-12.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115141/115141 [00:55<00:00, 2090.36it/s]
# 54/440-pcaps\Gosuna_LightBulb\2019-07-13.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115148/115148 [00:53<00:00, 2137.04it/s]
# 55/440-pcaps\Gosuna_LightBulb\2019-07-14.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115132/115132 [00:48<00:00, 2363.15it/s]
# 56/440-pcaps\Gosuna_LightBulb\2019-07-15.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115149/115149 [00:50<00:00, 2262.97it/s]
# 57/440-pcaps\Gosuna_LightBulb\2019-07-16.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115145/115145 [00:52<00:00, 2189.75it/s]
# 58/440-pcaps\Gosuna_LightBulb\2019-07-17.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115008/115008 [00:54<00:00, 2117.16it/s]
# 59/440-pcaps\Gosuna_LightBulb\2019-07-18.pcap
# 100%|████████████████████████████████████████████████████████████████████████| 115147/115147 [00:53<00:00, 2155.13it/s]
# 60/440-pcaps\Gosuna_LightBulb\2019-07-19.pcap
#  87%|██████████████████████████████████████████████████████████████▋         | 102795/118069 [00:50<00:08, 1849.35it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  91%|██████████████████████████████████████████████████████████████████▍      | 107415/118069 [00:55<00:13, 817.41it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  98%|██████████████████████████████████████████████████████████████████████▏ | 115143/118069 [01:00<00:01, 1817.35it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 118069/118069 [01:02<00:00, 1887.02it/s]
# 61/440-pcaps\Gosuna_Socket\2019-06-29.pcap
#  44%|███████████████████████████████▊                                         | 48043/110205 [00:21<00:27, 2269.65it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  94%|███████████████████████████████████████████████████████████████████▍    | 103238/110205 [00:46<00:03, 2208.22it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 110205/110205 [00:49<00:00, 2217.96it/s]
# 62/440-pcaps\Gosuna_Socket\2019-07-01.pcap
#  44%|███████████████████████████████▊                                         | 48162/110380 [00:20<00:25, 2479.31it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  67%|████████████████████████████████████████████████▌                        | 73448/110380 [00:31<00:17, 2062.07it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  84%|█████████████████████████████████████████████████████████████▏           | 92515/110380 [00:40<00:08, 2184.64it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  94%|███████████████████████████████████████████████████████████████████▍    | 103376/110380 [00:45<00:03, 2152.88it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#  94%|███████████████████████████████████████████████████████████████████▌    | 103615/110380 [00:45<00:03, 2158.48it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 110380/110380 [00:48<00:00, 2253.62it/s]
# 63/440-pcaps\Gosuna_Socket\2019-07-02.pcap
#  37%|███████████████████████████▎                                             | 37690/100939 [00:17<00:27, 2301.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  55%|████████████████████████████████████████                                 | 55477/100939 [00:25<00:19, 2297.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▉      | 92559/100939 [00:41<00:04, 2075.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 100939/100939 [00:45<00:00, 2207.49it/s]
# 64/440-pcaps\Gosuna_Socket\2019-07-03.pcap
#  43%|███████████████████████████████                                          | 48354/113621 [00:21<00:27, 2335.01it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  55%|████████████████████████████████████████▎                                | 62674/113621 [00:28<00:22, 2238.53it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|██████████████████████████████████████████████████████████████████▋     | 105230/113621 [00:47<00:03, 2180.35it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 113621/113621 [00:50<00:00, 2246.54it/s]
# 65/440-pcaps\Gosuna_Socket\2019-07-04.pcap
#  43%|███████████████████████████████▏                                         | 48546/113841 [00:22<00:28, 2276.66it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|██████████████████████████████████████████████████████████████████▋     | 105499/113841 [00:48<00:03, 2187.81it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 113841/113841 [00:52<00:00, 2181.36it/s]
# 66/440-pcaps\Gosuna_Socket\2019-07-05.pcap
#  43%|███████████████████████████████▏                                         | 48026/112562 [00:22<00:29, 2172.98it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|██████████████████████████████████████████████████████████████████▉     | 104662/112562 [00:47<00:03, 2200.80it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 112562/112562 [00:51<00:00, 2185.29it/s]
# 67/440-pcaps\Gosuna_Socket\2019-07-06.pcap
#  43%|███████████████████████████████▎                                         | 48725/113709 [00:20<00:26, 2419.24it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|██████████████████████████████████████████████████████████████████▋     | 105403/113709 [00:44<00:03, 2613.46it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 113709/113709 [00:47<00:00, 2373.67it/s]
# 68/440-pcaps\Gosuna_Socket\2019-07-07.pcap
#  40%|████████████████████████████▊                                            | 48692/123130 [00:19<00:29, 2506.46it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|██████████████████████████████████████████████████████████████████▋     | 114041/123130 [00:45<00:03, 2438.15it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 123130/123130 [00:49<00:00, 2499.78it/s]
# 69/440-pcaps\Gosuna_Socket\2019-07-08.pcap
#  42%|██████████████████████████████▊                                          | 48617/115154 [00:19<00:27, 2430.90it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▍     | 106246/115154 [00:42<00:03, 2596.64it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115154/115154 [00:46<00:00, 2482.96it/s]
# 70/440-pcaps\Gosuna_Socket\2019-07-09.pcap
#  42%|██████████████████████████████▊                                          | 48590/115155 [00:19<00:26, 2500.91it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▍     | 106208/115155 [00:42<00:03, 2489.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115155/115155 [00:46<00:00, 2474.42it/s]
# 71/440-pcaps\Gosuna_Socket\2019-07-10.pcap
#  42%|██████████████████████████████▉                                          | 48738/115073 [00:19<00:25, 2601.93it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▌     | 106393/115073 [00:42<00:03, 2599.20it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115073/115073 [00:45<00:00, 2521.80it/s]
# 72/440-pcaps\Gosuna_Socket\2019-07-11.pcap
#  42%|██████████████████████████████▊                                          | 48685/115241 [00:19<00:26, 2539.47it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  42%|███████████████████████████████                                          | 48940/115241 [00:19<00:26, 2510.50it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  62%|█████████████████████████████████████████████▌                           | 71986/115241 [00:28<00:17, 2482.47it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▍     | 106413/115241 [00:42<00:03, 2456.06it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115241/115241 [00:45<00:00, 2509.74it/s]
# 73/440-pcaps\Gosuna_Socket\2019-07-12.pcap
#  38%|███████████████████████████▉                                             | 44146/115158 [00:18<00:29, 2442.65it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▌     | 106467/115158 [00:43<00:03, 2769.94it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115158/115158 [00:46<00:00, 2471.80it/s]
# 74/440-pcaps\Gosuna_Socket\2019-07-13.pcap
#  43%|███████████████████████████████                                          | 48951/115160 [00:19<00:26, 2509.44it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▌     | 106498/115160 [00:42<00:03, 2537.34it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115160/115160 [00:46<00:00, 2492.47it/s]
# 75/440-pcaps\Gosuna_Socket\2019-07-14.pcap
#  43%|███████████████████████████████                                          | 48981/115189 [00:19<00:26, 2506.11it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  82%|███████████████████████████████████████████████████████████▉             | 94585/115189 [00:37<00:08, 2526.81it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  98%|██████████████████████████████████████████████████████████████████████▏ | 112333/115189 [00:44<00:01, 2523.64it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115189/115189 [00:45<00:00, 2543.85it/s]
# 76/440-pcaps\Gosuna_Socket\2019-07-15.pcap
#  37%|██████████████████████████▉                                              | 42504/115166 [00:16<00:27, 2643.57it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|██████████████████████████████████████████████████████████████████▋     | 106677/115166 [00:42<00:03, 2494.09it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115166/115166 [00:45<00:00, 2505.60it/s]
# 77/440-pcaps\Gosuna_Socket\2019-07-16.pcap
#  43%|███████████████████████████████                                          | 49090/115156 [00:19<00:25, 2565.07it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|██████████████████████████████████████████████████████████████████▋     | 106643/115156 [00:42<00:03, 2532.34it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115156/115156 [00:45<00:00, 2528.02it/s]
# 78/440-pcaps\Gosuna_Socket\2019-07-17.pcap
#  35%|█████████████████████████▋                                               | 40448/115221 [00:16<00:29, 2560.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  86%|██████████████████████████████████████████████████████████████▌          | 98783/115221 [00:39<00:06, 2563.50it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115221/115221 [00:46<00:00, 2496.35it/s]
# 79/440-pcaps\Gosuna_Socket\2019-07-18.pcap
#  36%|██████████████████████████                                               | 41192/115219 [00:16<00:30, 2458.85it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  51%|█████████████████████████████████████▎                                   | 58876/115219 [00:23<00:23, 2420.44it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|██████████████████████████████████████████████████████████████████▉     | 107036/115219 [00:43<00:03, 2555.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 115219/115219 [00:46<00:00, 2481.15it/s]
# 80/440-pcaps\Gosuna_Socket\2019-07-19.pcap
#  42%|██████████████████████████████▌                                          | 49191/117334 [00:19<00:26, 2569.10it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  71%|███████████████████████████████████████████████████▋                     | 82998/117334 [00:33<00:13, 2474.86it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  88%|███████████████████████████████████████████████████████████████         | 102867/117334 [00:41<00:05, 2518.90it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  95%|████████████████████████████████████████████████████████████████████    | 110973/117334 [00:46<00:02, 2415.16it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████| 117334/117334 [00:49<00:00, 2360.06it/s]
# 81/440-pcaps\Goumia_Coffemaker\2019-06-29.pcap
#   9%|██████▌                                                                    | 1686/19339 [00:00<00:05, 3202.19it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#  11%|███████▉                                                                   | 2031/19339 [00:00<00:05, 3240.16it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|█████████████████████████████████████████████████████████████████████     | 18062/19339 [00:05<00:00, 3174.46it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 19339/19339 [00:06<00:00, 3210.01it/s]
# 82/440-pcaps\Goumia_Coffemaker\2019-07-01.pcap
#  18%|█████████████▌                                                             | 3492/19388 [00:01<00:04, 3317.03it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 19388/19388 [00:06<00:00, 3190.27it/s]
# 83/440-pcaps\Goumia_Coffemaker\2019-07-02.pcap
#   2%|█▏                                                                          | 286/18030 [00:00<00:06, 2830.51it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#   3%|██▌                                                                         | 611/18030 [00:00<00:05, 2969.64it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 18030/18030 [00:05<00:00, 3221.28it/s]
# 84/440-pcaps\Goumia_Coffemaker\2019-07-03.pcap
#   6%|████▌                                                                      | 1201/19710 [00:00<00:05, 3598.36it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  97%|████████████████████████████████████████████████████████████████████████  | 19192/19710 [00:06<00:00, 3267.21it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 19710/19710 [00:06<00:00, 3183.04it/s]
# 85/440-pcaps\Goumia_Coffemaker\2019-07-04.pcap
#  18%|█████████████▏                                                             | 3474/19689 [00:01<00:04, 3296.15it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 19689/19689 [00:05<00:00, 3285.60it/s]
# 86/440-pcaps\Goumia_Coffemaker\2019-07-05.pcap
#   2%|█▍                                                                          | 359/19644 [00:00<00:05, 3301.73it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  84%|██████████████████████████████████████████████████████████████▎           | 16528/19644 [00:05<00:00, 3173.32it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 19644/19644 [00:06<00:00, 3160.90it/s]
# 87/440-pcaps\Goumia_Coffemaker\2019-07-06.pcap
#   5%|████                                                                       | 1053/19636 [00:00<00:06, 2943.44it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  90%|██████████████████████████████████████████████████████████████████▌       | 17647/19636 [00:05<00:00, 3167.53it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 19636/19636 [00:06<00:00, 3128.81it/s]
# 88/440-pcaps\Goumia_Coffemaker\2019-07-07.pcap
#   9%|███████                                                                    | 2026/21388 [00:00<00:05, 3234.81it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|█████████████████████████████████████████████████████████████████████     | 19957/21388 [00:06<00:00, 3231.24it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 21388/21388 [00:06<00:00, 3166.39it/s]
# 89/440-pcaps\Goumia_Coffemaker\2019-07-08.pcap
#  13%|█████████▉                                                                 | 2640/19916 [00:00<00:05, 3080.48it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  96%|███████████████████████████████████████████████████████████████████████   | 19123/19916 [00:06<00:00, 3187.62it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|██████████████████████████████████████████████████████████████████████████| 19916/19916 [00:06<00:00, 3068.05it/s]
# 90/440-pcaps\Goumia_Coffemaker\2019-07-09.pcap
#  17%|████████████▉                                                              | 3412/19836 [00:01<00:05, 3146.73it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# ...
#  82%|████████████████████████████████████████████████████████████▏            | 297670/361326 [11:40<02:15, 469.43it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  83%|████████████████████████████████████████████████████████████▌            | 299935/361326 [11:45<02:12, 462.74it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  84%|█████████████████████████████████████████████████████████████            | 302121/361326 [11:50<02:19, 425.49it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  84%|█████████████████████████████████████████████████████████████▍           | 304268/361326 [11:55<02:11, 435.47it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  85%|█████████████████████████████████████████████████████████████▉           | 306475/361326 [12:00<02:04, 441.97it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  85%|██████████████████████████████████████████████████████████████▎          | 308619/361326 [12:05<01:43, 511.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  86%|██████████████████████████████████████████████████████████████▊          | 310753/361326 [12:10<01:57, 431.41it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#  86%|██████████████████████████████████████████████████████████████▊          | 310803/361326 [12:10<01:52, 450.87it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  87%|███████████████████████████████████████████████████████████████▏         | 313025/361326 [12:15<01:34, 508.48it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  87%|███████████████████████████████████████████████████████████████▋         | 315204/361326 [12:20<01:46, 432.44it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  88%|████████████████████████████████████████████████████████████████         | 317326/361326 [12:25<01:49, 400.26it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  88%|████████████████████████████████████████████████████████████████▌        | 319598/361326 [12:30<01:13, 568.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  89%|█████████████████████████████████████████████████████████████████        | 321998/361326 [12:35<01:31, 430.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  90%|█████████████████████████████████████████████████████████████████▍       | 324100/361326 [12:40<01:26, 429.23it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  91%|█████████████████████████████████████████████████████████████████▎      | 327678/361326 [12:45<00:33, 1018.95it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▊      | 330914/361326 [12:50<00:50, 606.38it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|███████████████████████████████████████████████████████████████████▎     | 333175/361326 [12:55<01:04, 434.52it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|███████████████████████████████████████████████████████████████████▊     | 335549/361326 [13:00<00:59, 432.66it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|████████████████████████████████████████████████████████████████████▏    | 337708/361326 [13:05<00:55, 428.63it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  94%|████████████████████████████████████████████████████████████████████▋    | 339876/361326 [13:10<00:38, 559.94it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  95%|█████████████████████████████████████████████████████████████████████    | 342122/361326 [13:15<00:37, 515.84it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  95%|█████████████████████████████████████████████████████████████████████▌   | 344620/361326 [13:20<00:37, 440.07it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  96%|██████████████████████████████████████████████████████████████████████   | 346848/361326 [13:25<00:31, 462.98it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  97%|██████████████████████████████████████████████████████████████████████▌  | 349062/361326 [13:30<00:26, 467.14it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  97%|██████████████████████████████████████████████████████████████████████▉  | 351262/361326 [13:35<00:24, 417.40it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  98%|███████████████████████████████████████████████████████████████████████▌ | 354041/361326 [13:40<00:07, 962.94it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  99%|███████████████████████████████████████████████████████████████████████▉ | 356375/361326 [13:45<00:09, 496.68it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  99%|████████████████████████████████████████████████████████████████████████▎| 358119/361326 [13:50<00:07, 410.45it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████▋| 359983/361326 [13:55<00:03, 399.38it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|█████████████████████████████████████████████████████████████████████████| 361326/361326 [13:59<00:00, 430.40it/s]
# 421/440-pcaps\Wemo_SmartPlug\2019-06-29.pcap
#   0%|                                                                                         | 0/4273 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4273/4273 [00:01<00:00, 2159.49it/s]
# 422/440-pcaps\Wemo_SmartPlug\2019-07-01.pcap
#  50%|██████████████████████████████████████                                      | 2157/4314 [00:00<00:00, 2318.39it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4314/4314 [00:02<00:00, 1876.12it/s]
# 423/440-pcaps\Wemo_SmartPlug\2019-07-02.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3757/3757 [00:01<00:00, 1981.23it/s]
# 424/440-pcaps\Wemo_SmartPlug\2019-07-03.pcap
#   0%|                                                                                         | 0/3502 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3502/3502 [00:01<00:00, 1971.04it/s]
# 425/440-pcaps\Wemo_SmartPlug\2019-07-04.pcap
#  78%|███████████████████████████████████████████████████████████▏                | 2859/3670 [00:01<00:00, 1832.02it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3670/3670 [00:01<00:00, 1961.54it/s]
# 426/440-pcaps\Wemo_SmartPlug\2019-07-05.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3875/3875 [00:02<00:00, 1709.00it/s]
# 427/440-pcaps\Wemo_SmartPlug\2019-07-06.pcap
#   0%|                                                                                         | 0/3569 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3569/3569 [00:01<00:00, 1803.15it/s]
# 428/440-pcaps\Wemo_SmartPlug\2019-07-07.pcap
#  61%|██████████████████████████████████████████████▌                             | 2359/3854 [00:01<00:00, 1940.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3854/3854 [00:02<00:00, 1817.22it/s]
# 429/440-pcaps\Wemo_SmartPlug\2019-07-08.pcap
#  94%|███████████████████████████████████████████████████████████████████████▌    | 3640/3863 [00:02<00:00, 1538.29it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3863/3863 [00:02<00:00, 1662.99it/s]
# 430/440-pcaps\Wemo_SmartPlug\2019-07-09.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3850/3850 [00:02<00:00, 1892.92it/s]
# 431/440-pcaps\Wemo_SmartPlug\2019-07-10.pcap
#   0%|                                                                                         | 0/3989 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3989/3989 [00:02<00:00, 1926.33it/s]
# 432/440-pcaps\Wemo_SmartPlug\2019-07-11.pcap
#  48%|████████████████████████████████████▎                                       | 1939/4061 [00:00<00:00, 2158.38it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  54%|█████████████████████████████████████████▎                                  | 2209/4061 [00:00<00:00, 2282.62it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4061/4061 [00:02<00:00, 1862.44it/s]
# 433/440-pcaps\Wemo_SmartPlug\2019-07-12.pcap
#  81%|█████████████████████████████████████████████████████████████▉              | 3242/3980 [00:01<00:00, 1484.72it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3980/3980 [00:02<00:00, 1833.13it/s]
# 434/440-pcaps\Wemo_SmartPlug\2019-07-13.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3723/3723 [00:02<00:00, 1796.32it/s]
# 435/440-pcaps\Wemo_SmartPlug\2019-07-14.pcap
#   0%|                                                                                         | 0/4339 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4339/4339 [00:02<00:00, 1708.50it/s]
# 436/440-pcaps\Wemo_SmartPlug\2019-07-15.pcap
#  32%|████████████████████████▎                                                   | 1261/3933 [00:00<00:01, 2032.04it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3933/3933 [00:02<00:00, 1707.91it/s]
# 437/440-pcaps\Wemo_SmartPlug\2019-07-16.pcap
#  85%|████████████████████████████████████████████████████████████████▎           | 3314/3913 [00:01<00:00, 1565.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3913/3913 [00:02<00:00, 1828.13it/s]
# 438/440-pcaps\Wemo_SmartPlug\2019-07-17.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 4229/4229 [00:02<00:00, 1787.58it/s]
# 439/440-pcaps\Wemo_SmartPlug\2019-07-18.pcap
#   0%|                                                                                         | 0/3986 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3986/3986 [00:02<00:00, 1879.73it/s]
# 440/440-pcaps\Wemo_SmartPlug\2019-07-19.pcap
#  57%|███████████████████████████████████████████▏                                | 2357/4142 [00:01<00:00, 2189.53it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4142/4142 [00:02<00:00, 1717.05it/s]

# %% [markdown]
# # WIRESHARK FEATURES dst,src and Protocol added

# %%
name_list=find_the_way('./pcaps','_WS.csv')

for i in name_list:
    df=pd.read_csv(i)
    df=df[df["_ws.col.Protocol"]!="ARP"]
    df.to_csv(i,index=None)

# %%
name_list=find_the_way('./pcaps','_FE.csv')
name_list
# Out:
# ['./pcaps\\Chime_Doorbell\\2019-06-29_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-01_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-02_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-03_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-04_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-05_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-06_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-07_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-08_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-09_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-10_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-11_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-12_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-13_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-14_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-15_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-16_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-17_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-18_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-19_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-06-29_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-01_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-02_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-03_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-04_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-05_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-06_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-07_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-08_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-09_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-10_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-11_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-12_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-13_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-14_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-15_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-16_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-17_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-18_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-19_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-06-29_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-01_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-02_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-03_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-04_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-05_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-06_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-07_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-08_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-09_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-10_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-11_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-12_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-13_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-14_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-15_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-16_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-17_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-18_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-19_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-06-29_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-01_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-02_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-03_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-04_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-05_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-06_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-07_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-08_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-09_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-10_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-11_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-12_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-13_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-14_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-15_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-16_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-17_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-18_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-19_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-06-29_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-01_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-02_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-03_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-04_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-05_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-06_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-07_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-08_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-09_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-10_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-11_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-12_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-13_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-14_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-15_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-16_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-17_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-18_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-19_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-06-29_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-01_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-02_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-03_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-04_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-05_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-06_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-07_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-08_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-09_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-10_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-11_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-12_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-13_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-14_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-15_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-16_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-17_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-18_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-19_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-06-29_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-01_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-02_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-03_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-04_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-05_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-06_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-07_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-08_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-09_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-10_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-11_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-12_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-13_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-14_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-15_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-16_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-17_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-18_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-19_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-06-29_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-01_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-02_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-03_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-04_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-05_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-06_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-07_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-08_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-09_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-10_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-11_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-12_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-13_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-14_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-15_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-16_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-17_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-18_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-19_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-06-29_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-01_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-02_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-03_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-04_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-05_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-06_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-07_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-08_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-09_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-10_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-11_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-12_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-13_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-14_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-15_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-16_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-17_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-18_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-19_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-19_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-06-29_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-01_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-02_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-03_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-04_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-05_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-06_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-07_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-08_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-09_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-10_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-11_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-12_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-13_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-14_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-15_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-16_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-17_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-18_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-19_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-06-29_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-01_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-02_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-03_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-04_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-05_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-06_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-07_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-08_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-09_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-10_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-11_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-12_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-13_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-14_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-15_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-16_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-17_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-18_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-19_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-19_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-19_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-06-29_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-01_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-02_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-03_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-04_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-05_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-06_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-07_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-08_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-09_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-10_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-11_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-12_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-13_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-14_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-15_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-16_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-17_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-18_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-19_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-06-29_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-01_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-02_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-03_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-04_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-05_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-06_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-07_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-08_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-09_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-10_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-11_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-12_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-13_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-14_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-15_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-16_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-17_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-18_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-19_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-06-29_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-01_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-02_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-03_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-04_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-05_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-06_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-07_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-08_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-09_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-10_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-11_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-12_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-13_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-14_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-15_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-16_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-17_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-18_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-19_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-06-29_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-01_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-02_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-03_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-04_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-05_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-06_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-07_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-08_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-09_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-10_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-11_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-12_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-13_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-14_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-15_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-16_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-17_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-18_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-19_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-06-29_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-01_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-02_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-03_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-04_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-05_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-06_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-07_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-08_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-09_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-10_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-11_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-12_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-13_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-14_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-15_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-16_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-17_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-18_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-19_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-19_FE.csv',
#  './pcaps\\Wans_Cam\\2019-06-29_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-01_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-02_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-03_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-04_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-05_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-06_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-07_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-08_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-09_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-10_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-11_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-12_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-13_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-14_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-15_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-16_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-17_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-18_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-19_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-19_FE.csv']

# %%
for i in tqdm(name_list):
    df=pd.read_csv(i)
    WS_s_d=i.replace("_FE.csv","_WS.csv")
    s_d=pd.read_csv(WS_s_d)
    df["WS_src"]=s_d["_ws.col.Source"]
    df["WS_dst"]=s_d["_ws.col.Destination"]
    df["Protocol"]=s_d["_ws.col.Protocol"]
    y=df["Label"]
    df["MAC"]=df["Ether_src"]
    del df["Label"]
    df["Label"]=y
    df.to_csv(i,index=None) 
    flag_fixer(i)
    os.remove(WS_s_d)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 440/440 [41:06<00:00,  5.61s/it]

# %%
# !shutdown /s /t 1000

# %%
import pandas as pd
import os
import time
from tqdm import tqdm
import shutil
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
def folder(f_name): #this function creates a folder named "attacks" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
def find_the_way(path,file_format,con=""):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                if con in file:
                    files_add.append(os.path.join(r, file))  
            
    return files_add
path="pcaps"
files_add=find_the_way(path,'.pcap')

files_add=files_add[404:]

# %%
"""
essiz=[]
new=[]
for i in files_add:
    temp=i[:-16]
    if temp not in essiz:
        essiz.append(temp)
        new.append(i)
        print(temp)"""
# Out:
# '\nessiz=[]\nnew=[]\nfor i in files_add:\n    temp=i[:-16]\n    if temp not in essiz:\n        essiz.append(temp)\n        new.append(i)\n        print(temp)'

# %%
MAC_list={":\\xe8\\x13ua\\x00\\x00'":['2c:3a:e8:13:75:61', 'oossxx_SmartPlug'],
          "b',:\\xe8\\x13ua\\x00\\x00'":['2c:3a:e8:13:75:61', 'oossxx_SmartPlug'],
 "b'$\\xf5\\xa2\\xff\\xad\\x97\\x00\\x00'":['24:f5:a2:ff:ad:97', 'Wemo_SmartPlug'],
 "b'(\\xad>r\\xbd~\\x00\\x00'":['28:ad:3e:72:bd:7e', 'Wans_Cam'],
 "b'4\\x03\\xde\\x14\\xdc;\\x00\\x00'":['34:03:de:14:dc:3b', 'Ring_Doorbell'],
 "b'P\\xc7\\xbf\\xeb\\xec\\xc4\\x00\\x00'":[ '50:c7:bf:eb:ec:c4', 'tp-link_LightBulb'],
 "b'\\x00\\xe0Lq\\xb6\\xb6\\x00\\x00'":[ '00:e0:4c:71:b6:b6', 'Minger_LightStrip'],
 "b'\\x0c\\x80ced\\xde\\x00\\x00'": ['0c:80:63:65:64:de', 'tp-link_SmartPlug'],
 "b'\\x14k\\x9c\\x85\\x8a\\xfe\\x00\\x00'":[ '14:6b:9c:85:8a:fe', 'Tenvis_Cam'],
 "b'\\x84 \\x96\\x90C\\xe6\\x00\\x00'":[ '84:20:96:90:43:e6', 'itTiot_Cam'],
 "b'\\x84\\r\\x8e@\\x04T\\x00\\x00'": ['84:0d:8e:40:04:54', 'Lumiman_SmartPlug'] ,
 "b'\\x84\\r\\x8e\\x80b\\x9a\\x00\\x00'":['84:0d:8e:80:62:9a', 'Smart_LightStrip'],
 "b'\\x84\\xf3\\xeb<\\x9eO\\x00\\x00'":[ '84:f3:eb:3c:9e:4f', 'LaCrosse_AlarmClock'],
 "b'\\x84\\xf3\\xeb\\x18\\x91\\xdd\\x00\\x00'":[ '84:f3:eb:18:91:dd', 'Goumia_Coffemaker'],
 "b'\\x84\\xf3\\xebwH\\x1f\\x00\\x00'":['84:f3:eb:77:48:1f', 'Gosuna_LightBulb'],
 "b'\\x88?J\\xf5\\xde\\xd0\\x00\\x00'":['88:3f:4a:f5:de:d0', 'Chime_Doorbell'],
 "b'\\xb2\\xc5TBy\\xf2\\x00\\x00'":['b2:c5:54:42:79:f2', 'D-Link_Cam936L'],
 "b'\\xbc\\xdd\\xc2\\xe1%)\\x00\\x00'":[ 'bc:dd:c2:e1:25:29', 'Smart_Lamp'],
 'b\'\\xdcO"\\x1b/\\xad\\x00\\x00\'':['dc:4f:22:1b:2f:ad', 'Lumiman_Bulb600'],
 "b'\\xec=\\xfdZ\\xbay\\x00\\x00'":[ 'ec:3d:fd:5a:ba:79', 'Ocean_Radio'],
 "b'`8\\xe0\\x12\\x83\\x8a\\x00\\x00'":["UNK","UNK"],
          "b'\\x00\\x13\\xef\\x83\\x00M\\x00\\x00'":["UNK","UNK"],
          ":\\xe8\\x13ua\\x00\\x00'":["UNK","UNK"],

 "b'`\\x01\\x94\\xa7\\xc9\\xfd\\x00\\x00'": ['60:01:94:a7:c9:fd', 'Renpho_SmartPlug'],
 "b'`\\x01\\x94\\xb6\\x1b)\\x00\\x00'":[ '60:01:94:b6:1b:29', 'Gosuna_Socket'],
 "b'`\\x01\\x94n?p\\x00\\x00'":['60:01:94:6e:3f:70', 'Lumiman_Bulb900']}

# %%
"<Flag 0 ()>"== '<Flag 0 ()>'
# Out:
# True

# %%
def flag_fixer(file):

    IP_flags = {'0': 1, '<Flag 0 ()>': 2, '<Flag 2 (DF)>': 3, '<Flag 1 (MF)>': 4,'<Flag 3 (MF+DF)>':5,
     '<Flag 4 (evil)>':6,
     '<Flag 5 (MF+evil)>':7,
     '<Flag 6 (DF+evil)>':8,
     '<Flag 7 (MF+DF+evil)>':9,
     '<Flag 3 (MF+DF)>':10,
     '<Flag 4 (evil)>':11,
     '<Flag 5 (MF+evil)>':12,
     '<Flag 6 (DF+evil)>':13,
     '<Flag 7 (MF+DF+evil)>':14,
     '<Flag 3 (MF+DF)>':15,
     '<Flag 4 (evil)>':16,
     '<Flag 5 (MF+evil)>':17,
     '<Flag 6 (DF+evil)>':18,
     '<Flag 7 (MF+DF+evil)>':19,
     '<Flag 3 (MF+DF)>':20,
     '<Flag 4 (evil)>':21,
     '<Flag 5 (MF+evil)>':22,
     '<Flag 6 (DF+evil)>':23,
     '<Flag 7 (MF+DF+evil)>':24,
     '<Flag 3 (MF+DF)>':25,
     '<Flag 4 (evil)>':26,
     '<Flag 5 (MF+evil)>':27,
     '<Flag 6 (DF+evil)>':28,
     '<Flag 7 (MF+DF+evil)>':29,
     '<Flag 3 (MF+DF)>':30,
     '<Flag 4 (evil)>':31,
     '<Flag 5 (MF+evil)>':32,
     '<Flag 6 (DF+evil)>':33,
     '<Flag 7 (MF+DF+evil)>':34,
     '<Flag 3 (MF+DF)>':35,
     '<Flag 4 (evil)>':36,
     '<Flag 5 (MF+evil)>':37,
     '<Flag 6 (DF+evil)>':38,
     '<Flag 7 (MF+DF+evil)>':39,
     '<Flag 3 (MF+DF)>':40,
     '<Flag 4 (evil)>':41,
     '<Flag 5 (MF+evil)>':42,
     '<Flag 6 (DF+evil)>':43,
     '<Flag 7 (MF+DF+evil)>':44}
    TCP_flags = {'0': 1, '<Flag 2 (S)>': 2, '<Flag 18 (SA)>': 3, '<Flag 16 (A)>': 4, '<Flag 24 (PA)>': 5, '<Flag 25 (FPA)>': 6, '<Flag 17 (FA)>': 7, '<Flag 4 (R)>': 8, '<Flag 20 (RA)>': 9, '<Flag 194 (SEC)>': 10, '<Flag 1 (F)>': 11, '<Flag 152 (PAC)>': 12, '<Flag 144 (AC)>': 13,'<Flag 82 (SAE)>':14,'<Flag 49 (FAU)>':15, '<Flag 0 ()>':16,
     '<Flag 10 (SP)>':17,
     '<Flag 100 (RUE)>':18,
     '<Flag 102 (SRUE)>':19,
     '<Flag 103 (FSRUE)>':20,
     '<Flag 104 (PUE)>':21,
     '<Flag 106 (SPUE)>':22,
     '<Flag 108 (RPUE)>':23,
     '<Flag 11 (FSP)>':24,
     '<Flag 110 (SRPUE)>':25,
     '<Flag 111 (FSRPUE)>':26,
     '<Flag 112 (AUE)>':27,
     '<Flag 113 (FAUE)>':28,
     '<Flag 114 (SAUE)>':29,
     '<Flag 116 (RAUE)>':30,
     '<Flag 117 (FRAUE)>':31,
     '<Flag 119 (FSRAUE)>':32,
     '<Flag 121 (FPAUE)>':33,
     '<Flag 123 (FSPAUE)>':34,
     '<Flag 124 (RPAUE)>':35,
     '<Flag 125 (FRPAUE)>':36,
     '<Flag 126 (SRPAUE)>':37,
     '<Flag 127 (FSRPAUE)>':38,
     '<Flag 128 (C)>':39,
     '<Flag 129 (FC)>':40,
     '<Flag 13 (FRP)>':41,
     '<Flag 130 (SC)>':42,
     '<Flag 131 (FSC)>':43,
     '<Flag 133 (FRC)>':44,
     '<Flag 134 (SRC)>':45,
     '<Flag 135 (FSRC)>':46,
     '<Flag 136 (PC)>':47,
     '<Flag 137 (FPC)>':48,
     '<Flag 138 (SPC)>':49,
     '<Flag 139 (FSPC)>':50,
     '<Flag 14 (SRP)>':51,
     '<Flag 140 (RPC)>':52,
     '<Flag 145 (FAC)>':53,
     '<Flag 146 (SAC)>':54,
     '<Flag 147 (FSAC)>':55,
     '<Flag 148 (RAC)>':56,
     '<Flag 150 (SRAC)>':57,
     '<Flag 151 (FSRAC)>':58,
     '<Flag 153 (FPAC)>':59,
     '<Flag 154 (SPAC)>':60,
     '<Flag 155 (FSPAC)>':61,
     '<Flag 156 (RPAC)>':62,
     '<Flag 157 (FRPAC)>':63,
     '<Flag 158 (SRPAC)>':64,
     '<Flag 159 (FSRPAC)>':65,
     '<Flag 160 (UC)>':66,
     '<Flag 162 (SUC)>':67,
     '<Flag 163 (FSUC)>':68,
     '<Flag 164 (RUC)>':69,
     '<Flag 166 (SRUC)>':70,
     '<Flag 169 (FPUC)>':71,
     '<Flag 170 (SPUC)>':72,
     '<Flag 171 (FSPUC)>':73,
     '<Flag 172 (RPUC)>':74,
     '<Flag 174 (SRPUC)>':75,
     '<Flag 176 (AUC)>':76,
     '<Flag 177 (FAUC)>':77,
     '<Flag 179 (FSAUC)>':78,
     '<Flag 180 (RAUC)>':79,
     '<Flag 181 (FRAUC)>':80,
     '<Flag 182 (SRAUC)>':81,
     '<Flag 185 (FPAUC)>':82,
     '<Flag 186 (SPAUC)>':83,
     '<Flag 187 (FSPAUC)>':84,
     '<Flag 188 (RPAUC)>':85,
     '<Flag 190 (SRPAUC)>':86,
     '<Flag 191 (FSRPAUC)>':87,
     '<Flag 195 (FSEC)>':88,
     '<Flag 197 (FREC)>':89,
     '<Flag 199 (FSREC)>':90,
     '<Flag 200 (PEC)>':91,
     '<Flag 201 (FPEC)>':92,
     '<Flag 202 (SPEC)>':93,
     '<Flag 203 (FSPEC)>':94,
     '<Flag 204 (RPEC)>':95,
     '<Flag 205 (FRPEC)>':96,
     '<Flag 206 (SRPEC)>':97,
     '<Flag 207 (FSRPEC)>':98,
     '<Flag 208 (AEC)>':99,
     '<Flag 209 (FAEC)>':100,
     '<Flag 210 (SAEC)>':101,
     '<Flag 212 (RAEC)>':102,
     '<Flag 213 (FRAEC)>':103,
     '<Flag 214 (SRAEC)>':104,
     '<Flag 216 (PAEC)>':105,
     '<Flag 218 (SPAEC)>':106,
     '<Flag 219 (FSPAEC)>':107,
     '<Flag 22 (SRA)>':108,
     '<Flag 220 (RPAEC)>':109,
     '<Flag 222 (SRPAEC)>':110,
     '<Flag 224 (UEC)>':111,
     '<Flag 228 (RUEC)>':112,
     '<Flag 229 (FRUEC)>':113,
     '<Flag 23 (FSRA)>':114,
     '<Flag 232 (PUEC)>':115,
     '<Flag 233 (FPUEC)>':116,
     '<Flag 234 (SPUEC)>':117,
     '<Flag 236 (RPUEC)>':118,
     '<Flag 237 (FRPUEC)>':119,
     '<Flag 238 (SRPUEC)>':120,
     '<Flag 240 (AUEC)>':121,
     '<Flag 241 (FAUEC)>':122,
     '<Flag 242 (SAUEC)>':123,
     '<Flag 244 (RAUEC)>':124,
     '<Flag 246 (SRAUEC)>':125,
     '<Flag 248 (PAUEC)>':126,
     '<Flag 249 (FPAUEC)>':127,
     '<Flag 251 (FSPAUEC)>':128,
     '<Flag 252 (RPAUEC)>':129,
     '<Flag 253 (FRPAUEC)>':130,
     '<Flag 254 (SRPAUEC)>':131,
     '<Flag 255 (FSRPAUEC)>':132,
     '<Flag 256 (N)>':133,
     '<Flag 257 (FN)>':134,
     '<Flag 258 (SN)>':135,
     '<Flag 259 (FSN)>':136,
     '<Flag 26 (SPA)>':137,
     '<Flag 260 (RN)>':138,
     '<Flag 261 (FRN)>':139,
     '<Flag 262 (SRN)>':140,
     '<Flag 263 (FSRN)>':141,
     '<Flag 264 (PN)>':142,
     '<Flag 267 (FSPN)>':143,
     '<Flag 268 (RPN)>':144,
     '<Flag 270 (SRPN)>':145,
     '<Flag 272 (AN)>':146,
     '<Flag 273 (FAN)>':147,
     '<Flag 274 (SAN)>':148,
     '<Flag 275 (FSAN)>':149,
     '<Flag 276 (RAN)>':150,
     '<Flag 278 (SRAN)>':151,
     '<Flag 28 (RPA)>':152,
     '<Flag 280 (PAN)>':153,
     '<Flag 281 (FPAN)>':154,
     '<Flag 282 (SPAN)>':155,
     '<Flag 283 (FSPAN)>':156,
     '<Flag 285 (FRPAN)>':157,
     '<Flag 286 (SRPAN)>':158,
     '<Flag 287 (FSRPAN)>':159,
     '<Flag 288 (UN)>':160,
     '<Flag 29 (FRPA)>':161,
     '<Flag 291 (FSUN)>':162,
     '<Flag 292 (RUN)>':163,
     '<Flag 293 (FRUN)>':164,
     '<Flag 296 (PUN)>':165,
     '<Flag 297 (FPUN)>':166,
     '<Flag 298 (SPUN)>':167,
     '<Flag 3 (FS)>':168,
     '<Flag 30 (SRPA)>':169,
     '<Flag 301 (FRPUN)>':170,
     '<Flag 302 (SRPUN)>':171,
     '<Flag 306 (SAUN)>':172,
     '<Flag 307 (FSAUN)>':173,
     '<Flag 308 (RAUN)>':174,
     '<Flag 309 (FRAUN)>':175,
     '<Flag 31 (FSRPA)>':176,
     '<Flag 311 (FSRAUN)>':177,
     '<Flag 312 (PAUN)>':178,
     '<Flag 313 (FPAUN)>':179,
     '<Flag 314 (SPAUN)>':180,
     '<Flag 315 (FSPAUN)>':181,
     '<Flag 316 (RPAUN)>':182,
     '<Flag 318 (SRPAUN)>':183,
     '<Flag 32 (U)>':184,
     '<Flag 323 (FSEN)>':185,
     '<Flag 324 (REN)>':186,
     '<Flag 325 (FREN)>':187,
     '<Flag 326 (SREN)>':188,
     '<Flag 329 (FPEN)>':189,
     '<Flag 33 (FU)>':190,
     '<Flag 330 (SPEN)>':191,
     '<Flag 332 (RPEN)>':192,
     '<Flag 333 (FRPEN)>':193,
     '<Flag 335 (FSRPEN)>':194,
     '<Flag 336 (AEN)>':195,
     '<Flag 338 (SAEN)>':196,
     '<Flag 339 (FSAEN)>':197,
     '<Flag 34 (SU)>':198,
     '<Flag 340 (RAEN)>':199,
     '<Flag 341 (FRAEN)>':200,
     '<Flag 342 (SRAEN)>':201,
     '<Flag 343 (FSRAEN)>':202,
     '<Flag 344 (PAEN)>':203,
     '<Flag 347 (FSPAEN)>':204,
     '<Flag 348 (RPAEN)>':205,
     '<Flag 349 (FRPAEN)>':206,
     '<Flag 350 (SRPAEN)>':207,
     '<Flag 351 (FSRPAEN)>':208,
     '<Flag 352 (UEN)>':209,
     '<Flag 353 (FUEN)>':210,
     '<Flag 354 (SUEN)>':211,
     '<Flag 355 (FSUEN)>':212,
     '<Flag 356 (RUEN)>':213,
     '<Flag 357 (FRUEN)>':214,
     '<Flag 358 (SRUEN)>':215,
     '<Flag 359 (FSRUEN)>':216,
     '<Flag 36 (RU)>':217,
     '<Flag 361 (FPUEN)>':218,
     '<Flag 365 (FRPUEN)>':219,
     '<Flag 366 (SRPUEN)>':220,
     '<Flag 368 (AUEN)>':221,
     '<Flag 369 (FAUEN)>':222,
     '<Flag 37 (FRU)>':223,
     '<Flag 370 (SAUEN)>':224,
     '<Flag 372 (RAUEN)>':225,
     '<Flag 374 (SRAUEN)>':226,
     '<Flag 376 (PAUEN)>':227,
     '<Flag 377 (FPAUEN)>':228,
     '<Flag 378 (SPAUEN)>':229,
     '<Flag 379 (FSPAUEN)>':230,
     '<Flag 38 (SRU)>':231,
     '<Flag 380 (RPAUEN)>':232,
     '<Flag 383 (FSRPAUEN)>':233,
     '<Flag 384 (CN)>':234,
     '<Flag 385 (FCN)>':235,
     '<Flag 389 (FRCN)>':236,
     '<Flag 390 (SRCN)>':237,
     '<Flag 391 (FSRCN)>':238,
     '<Flag 392 (PCN)>':239,
     '<Flag 393 (FPCN)>':240,
     '<Flag 394 (SPCN)>':241,
     '<Flag 396 (RPCN)>':242,
     '<Flag 398 (SRPCN)>':243,
     '<Flag 40 (PU)>':244,
     '<Flag 401 (FACN)>':245,
     '<Flag 402 (SACN)>':246,
     '<Flag 403 (FSACN)>':247,
     '<Flag 404 (RACN)>':248,
     '<Flag 405 (FRACN)>':249,
     '<Flag 406 (SRACN)>':250,
     '<Flag 408 (PACN)>':251,
     '<Flag 409 (FPACN)>':252,
     '<Flag 41 (FPU)>':253,
     '<Flag 410 (SPACN)>':254,
     '<Flag 411 (FSPACN)>':255,
     '<Flag 412 (RPACN)>':256,
     '<Flag 413 (FRPACN)>':257,
     '<Flag 415 (FSRPACN)>':258,
     '<Flag 418 (SUCN)>':259,
     '<Flag 419 (FSUCN)>':260,
     '<Flag 42 (SPU)>':261,
     '<Flag 420 (RUCN)>':262,
     '<Flag 421 (FRUCN)>':263,
     '<Flag 422 (SRUCN)>':264,
     '<Flag 424 (PUCN)>':265,
     '<Flag 426 (SPUCN)>':266,
     '<Flag 427 (FSPUCN)>':267,
     '<Flag 43 (FSPU)>':268,
     '<Flag 433 (FAUCN)>':269,
     '<Flag 436 (RAUCN)>':270,
     '<Flag 437 (FRAUCN)>':271,
     '<Flag 438 (SRAUCN)>':272,
     '<Flag 44 (RPU)>':273,
     '<Flag 440 (PAUCN)>':274,
     '<Flag 442 (SPAUCN)>':275,
     '<Flag 444 (RPAUCN)>':276,
     '<Flag 445 (FRPAUCN)>':277,
     '<Flag 446 (SRPAUCN)>':278,
     '<Flag 447 (FSRPAUCN)>':279,
     '<Flag 448 (ECN)>':280,
     '<Flag 449 (FECN)>':281,
     '<Flag 450 (SECN)>':282,
     '<Flag 451 (FSECN)>':283,
     '<Flag 455 (FSRECN)>':284,
     '<Flag 456 (PECN)>':285,
     '<Flag 458 (SPECN)>':286,
     '<Flag 46 (SRPU)>':287,
     '<Flag 463 (FSRPECN)>':288,
     '<Flag 464 (AECN)>':289,
     '<Flag 465 (FAECN)>':290,
     '<Flag 466 (SAECN)>':291,
     '<Flag 467 (FSAECN)>':292,
     '<Flag 468 (RAECN)>':293,
     '<Flag 469 (FRAECN)>':294,
     '<Flag 47 (FSRPU)>':295,
     '<Flag 472 (PAECN)>':296,
     '<Flag 474 (SPAECN)>':297,
     '<Flag 475 (FSPAECN)>':298,
     '<Flag 476 (RPAECN)>':299,
     '<Flag 478 (SRPAECN)>':300,
     '<Flag 48 (AU)>':301,
     '<Flag 482 (SUECN)>':302,
     '<Flag 483 (FSUECN)>':303,
     '<Flag 484 (RUECN)>':304,
     '<Flag 485 (FRUECN)>':305,
     '<Flag 489 (FPUECN)>':306,
     '<Flag 491 (FSPUECN)>':307,
     '<Flag 492 (RPUECN)>':308,
     '<Flag 493 (FRPUECN)>':309,
     '<Flag 495 (FSRPUECN)>':310,
     '<Flag 497 (FAUECN)>':311,
     '<Flag 498 (SAUECN)>':312,
     '<Flag 5 (FR)>':313,
     '<Flag 50 (SAU)>':314,
     '<Flag 502 (SRAUECN)>':315,
     '<Flag 503 (FSRAUECN)>':316,
     '<Flag 505 (FPAUECN)>':317,
     '<Flag 507 (FSPAUECN)>':318,
     '<Flag 508 (RPAUECN)>':319,
     '<Flag 51 (FSAU)>':320,
     '<Flag 510 (SRPAUECN)>':321,
     '<Flag 511 (FSRPAUECN)>':322,
     '<Flag 52 (RAU)>':323,
     '<Flag 55 (FSRAU)>':324,
     '<Flag 56 (PAU)>':325,
     '<Flag 57 (FPAU)>':326,
     '<Flag 58 (SPAU)>':327,
     '<Flag 59 (FSPAU)>':328,
     '<Flag 6 (SR)>':329,
     '<Flag 61 (FRPAU)>':330,
     '<Flag 62 (SRPAU)>':331,
     '<Flag 66 (SE)>':332,
     '<Flag 67 (FSE)>':333,
     '<Flag 68 (RE)>':334,
     '<Flag 7 (FSR)>':335,
     '<Flag 72 (PE)>':336,
     '<Flag 73 (FPE)>':337,
     '<Flag 74 (SPE)>':338,
     '<Flag 75 (FSPE)>':339,
     '<Flag 76 (RPE)>':340,
     '<Flag 77 (FRPE)>':341,
     '<Flag 79 (FSRPE)>':342,
     '<Flag 8 (P)>':343,
     '<Flag 80 (AE)>':344,
     '<Flag 81 (FAE)>':345,
     '<Flag 83 (FSAE)>':346,
     '<Flag 84 (RAE)>':347,
     '<Flag 85 (FRAE)>':348,
     '<Flag 86 (SRAE)>':349,
     '<Flag 87 (FSRAE)>':350,
     '<Flag 88 (PAE)>':351,
     '<Flag 89 (FPAE)>':352,
     '<Flag 90 (SPAE)>':353,
     '<Flag 92 (RPAE)>':354,
     '<Flag 93 (FRPAE)>':355,
     '<Flag 94 (SRPAE)>':356,
     '<Flag 95 (FSRPAE)>':357,
     '<Flag 96 (UE)>':358,
     '<Flag 98 (SUE)>':359,
     '<Flag 99 (FSUE)>':360}
    BOOTP_flags = {'0': 1, '<Flag 0 ()>': 2, '<Flag 32768 (B)>': 3, 0: 1}
    Protocol = {'EAPOL': 1, 'DHCP': 2, 'DNS': 3, 'TCP': 4, 'HTTP': 5, 'ICMP': 6, 'MDNS': 7, 'IGMPv3': 8, 'SSDP': 9, 'NTP': 10, 'HTTP/XML': 11, 'UDP': 12, 'SSLv2': 13, 'TLSv1': 14, 'ADwin Config': 15, 'TLSv1.2': 16, 'ICMPv6': 17, 'HTTP/JSON': 18, 'XID': 19, 'TFTP': 20, 'NXP 802.15.4 SNIFFER': 21, 'IGMPv2': 22, 'A21': 23, 'STUN': 24, 'Gearman': 25, '? KNXnet/IP': 26, 'UDPENCAP': 27, 'ESP': 28, 'SSL': 29, 'NBNS': 30, 'SIP': 31, 'BROWSER': 32, 'SABP': 33, 'ISAKMP': 34, 'CLASSIC-STUN': 35, 'Omni-Path': 36, 'XMPP/XML': 37, 'ULP': 38, 'TFP over TCP': 39, 'AX4000': 40, 'MIH': 41, 'DHCPv6': 42, 'TDLS': 43, 'RTMP': 44, 'TCPCL': 45, 'IPA': 46, 'GQUIC': 47, '0x86dd': 48, 'DB-LSP-DISC': 49, 'SSLv3': 50, 'LLMNR': 51, 'FB_ZERO': 52, 'OCSP': 53, 'IPv4': 54, 'STP': 55, 'SSH': 56, 'TLSv1.1': 57, 'KINK': 58, 'MANOLITO': 59, 'PKTC': 60, 'TELNET': 61, 'RTSP': 62, 'HCrt': 63, 'MPTCP': 64, 'S101': 65, 'IRC': 66, 'AJP13': 67, 'PMPROXY': 68, 'PNIO': 69, 'AMS': 70, 'ECATF': 71, 'LLC': 72, 'TZSP': 73,'RSIP':74,'SSHv2':75
    ,'DIAMETER':76
    ,'BFD Control':77
    ,'ASAP':78
    ,'DISTCC':79 
    ,'DISTCC ':79       
    ,'LISP':80
    ,'WOW':81
    ,'DTLSv1.0':82
    ,'SNMP':83
    ,'SMB2':84
    ,'SMB':85
    ,'NBSS':86
    ,'UDT':87,'HiQnet':88
    ,'POWERLINK/UDP':89
    ,'RTP':90
    ,'WebSocket':91
    ,'NAT-PMP':92
    ,'RTCP':93,'Syslog':94
    ,'Portmap':95
    ,'OpenVPN':96
    ,'BJNP':97
    ,'RIPv1':98
    ,'MAC-Telnet':99
    ,'ECHO':100
    ,'ASF':101
    ,'DAYTIME':102
    ,'SRVLOC':103
    ,'KRB4':104
    ,'CAPWAP-Control':105
    ,'XDMCP':106
    ,'Chargen':107
    ,'RADIUS':108
    ,'L2TP':109
    ,'DCERPC':110
    ,'KPASSWD':111
    ,'H264':112
    ,'FTP':113
    ,'FTP-DATA':114
    ,'ENIP':115
    ,'RIPv2':116
    ,'ICP':117,
    "BACnet-APDU":118,
    "IAX2":119,
    "RX":120,
    "HTTP2":121,
    "SIP/SDP":122,
    "TIME":123,
    "Elasticsearch":124,
    "RSL":125,
    "TPCP":126,
     "IPv6":  127,"ARP":  128 }

    df=pd.read_csv(file)
    IP_flags
    
    df["IP_flags"]=df["IP_flags"].map(IP_flags.get)
    #df["TCP_flags"]=df["TCP_flags"].map(TCP_flags.get)
    df["BOOTP_flags"]=df["BOOTP_flags"].map(BOOTP_flags.get)
    #df["Protocol"]=df["Protocol"].map(Protocol.get)
    
    #df=df.replace({"IP_flags": IP_flags})
    #df=df.replace({"TCP_flags": TCP_flags})
    #df=df.replace({"BOOTP_flags": BOOTP_flags})
    #df=df.replace({"Protocol": Protocol})
    #df=df.replace({"Label": label})
    df.to_csv(file,index=None)

# %% [markdown]
# # PCAP2CSV

# %%
from scapy.all import*

# %%
import math
import pandas as pd
import os
import numpy as np

# %%
def folder(f_name): #this function creates a folder.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
def shannon(data):
    LOG_BASE = 2
   # We determine the frequency of each byte
   # in the dataset and if this frequency is not null we use it for the
   # entropy calculation
    dataSize = len(data)
    ent = 0.0
    freq={} 
    for c in data:
        if c in freq:
            freq[c] += 1
        else:
            freq[c] = 1
   # to determine if each possible value of a byte is in the list
    for key in freq.keys():
        f = float(freq[key])/dataSize
        if f > 0: # to avoid an error for log(0)
            ent = ent + f * math.log(f, LOG_BASE)
    return -ent

def pre_entropy(payload):
    
    characters=[]
    for i in payload:
            characters.append(i)
    return shannon(characters)

# %%
def port_class(port):
    port_list=[0,53,67,68,80,123,443,1900,5353,49153]# private port list (0-Reserved,53-DNS, 67-BOOTP server, 68-BOOTP client...)
    if port in port_list: #Is the port number in the list?
        return port_list.index(port)+1 # return the port's index number in the list (actually with index+1)
    elif 0 <= port <= 1023: # return 11 if the port number is in the range 0 :1023
        return 11
    elif  1024 <= port <= 49151 : # return 12 if the port number is in the range 1024:49151
        return 12
    elif 49152 <=port <= 65535 :# return 13 if the port number is in the range 49152:65535
        return 13
    else:# return 0 if no previous conditions are met
        return 0
    
    
def port_1023(port):
    if 0 <= port <= 1023:
        return port
    elif  1024 <= port <= 49151 :
        return 2
    elif 49152 <=port <= 65535 :
        return 3
    else:
        return 0

# %%
header="ts,Ether_dst,Ether_src,IP_src,IP_dst,pck_size,Ether_type,LLC_dsap,LLC_ssap,LLC_ctrl,EAPOL_version,EAPOL_type,EAPOL_len,IP_version,IP_ihl,IP_tos,IP_len,IP_flags,IP_Z,IP_MF,IP_id,IP_chksum,IP_DF,IP_frag,IP_ttl,IP_proto,IP_options,ICMP_type,ICMP_code,ICMP_chksum,ICMP_id,ICMP_seq,ICMP_ts_ori,ICMP_ts_rx,ICMP_ts_tx,ICMP_ptr,ICMP_reserved,ICMP_length,ICMP_nexthopmtu,ICMP_unused,TCP_seq,TCP_ack,TCP_dataofs,TCP_reserved,TCP_flags,TCP_FIN,TCP_SYN,TCP_RST,TCP_PSH,TCP_ACK,TCP_URG,TCP_ECE,TCP_CWR,TCP_window,TCP_chksum,TCP_urgptr,TCP_options,UDP_len,UDP_chksum,DHCP_options,BOOTP_op,BOOTP_htype,BOOTP_hlen,BOOTP_hops,BOOTP_xid,BOOTP_secs,BOOTP_flags,BOOTP_sname,BOOTP_file,BOOTP_options,DNS_length,DNS_id,DNS_qr,DNS_opcode,DNS_aa,DNS_tc,DNS_rd,DNS_ra,DNS_z,DNS_ad,DNS_cd,DNS_rcode,DNS_qdcount,DNS_ancount,DNS_nscount,DNS_arcount,sport_class,dport_class,sport23,dport23,sport_bare,dport_bare,TCP_sport,TCP_dport,UDP_sport,UDP_dport,payload_bytes,entropy,Label\n"

#header="pck_size,Ether_type,LLC_dsap,LLC_ssap,LLC_ctrl,EAPOL_version,EAPOL_type,EAPOL_len,IP_version,IP_ihl,IP_tos,IP_len,IP_flags,IP_frag,IP_ttl,IP_proto,IP_options,IP_add_count,ICMP_type,ICMP_code,ICMP_seq,ICMP_ts_ori,ICMP_ts_rx,ICMP_ts_tx,ICMP_gw,ICMP_ptr,ICMP_reserved,ICMP_length,ICMP_nexthopmtu,ICMP_unused,TCP_dataofs,TCP_reserved,TCP_flags,TCP_window,TCP_urgptr,UDP_len,BOOTP_op,BOOTP_htype,BOOTP_hlen,BOOTP_hops,BOOTP_secs,BOOTP_flags,DNS_length,DNS_qr,DNS_opcode,DNS_aa,DNS_tc,DNS_rd,DNS_ra,DNS_z,DNS_ad,DNS_cd,DNS_rcode,DNS_qdcount,DNS_ancount,DNS_nscount,DNS_arcount,sport,dport,entropy,Label,MAC\n"

# %%
#flags
#TCP
FIN = 0x01
SYN = 0x02
RST = 0x04
PSH = 0x08
ACK = 0x10
URG = 0x20
ECE = 0x40
CWR = 0x80
#IP
Z = 0x00
MF= 0x01
DF= 0x02

# %% [markdown]
# # Individual paket pased faetures

# %%
def pcap_parser(oldname):
    piece_size=50000
    new_name=oldname.replace(".pcap","_smaller.pcap")
    command='C:/\"Program Files\"/Wireshark/editcap.exe -c '+str(piece_size)+" \""+oldname+"\" "+new_name   
    os.system(command)
    parsed=find_the_way("./",new_name[6:-5])
    return parsed,new_name[6:-5]

# %%
def merged_csv(name,keyword):
    for merger in ["_FE.csv","_WS.csv"]:
        merged_name=f"{name[:-4]}{merger}"
        csv_files=find_the_way("./",keyword,merger)
        df=pd.read_csv(csv_files[0])
        col_names=list(df.columns)

        empty = pd.DataFrame(columns=col_names)
        empty.to_csv(merged_name, mode="w", index=False)#,header=False)


        for j in csv_files:

            df=pd.read_csv(j)
            #print("name and shape of dataframe :",i,df.shape)
            df.to_csv(merged_name, mode="a", index=False,header=False)


            os.remove(j)
            try:
                os.remove(j.replace("_FE.csv",".pcap"))
            except:pass

            #print("\n\n\nname and shape of dataframe :",name,df.shape)

# %%
outputfolder="FE"
folder(outputfolder)




for sayac,i in enumerate (files_add):
    print(f"{sayac+1}/{len(files_add)}-{i}")
    boyut=os.path.getsize(i)
    label_count=0
    if boyut >100000000:
        file_list,keyword=pcap_parser(i)

    else:
        file_list=[i]    
    for isim in file_list:
    
        filename=isim.replace(".pcap","_FE.csv")
        ths = open(filename, "w")
        ths.write(header)  
 
    
    
        pkt = rdpcap(isim)
        for j in tqdm(pkt):
            
            if j.haslayer(ARP):
                continue
            else:
                ts=float(j.time)
                try:pck_size=j.len
                except:pck_size=0
                if j.haslayer(Ether):


                    Ether_dst=j[Ether].dst#Ether_adresses.index(j[Ether].dst)+1
                    Ether_src=j[Ether].src#Ether_adj[Ether].dstresses.index(j[Ether].src)+1


                    Ether_type=j[Ether].type
                else:
                    Ether_dst=0
                    try:Ether_src=MAC_list[str(j.src)][0]
                    except:
                        #print(str(j.src))
                        Ether_src="UNK"
                    Ether_type=0


                if j.haslayer(ARP):
                    ARP_hwtype=j[ARP].hwtype
                    ARP_ptype=j[ARP].ptype
                    ARP_hwlen=j[ARP].hwlen
                    ARP_plen=j[ARP].plen
                    ARP_op=j[ARP].op


                    ARP_hwsrc=j[ARP].hwsrc
                    ARP_psrc=j[ARP].psrc
                    ARP_hwdst=j[ARP].hwdst
                    ARP_pdst=j[ARP].pdst




                    ARP_hwsrc=j[ARP].hwsrc#Ether_adresses.index(j[ARP].hwsrc)+1
                    ARP_psrc=j[ARP].psrc#IP_adresses.index(j[ARP].psrc)+1
                    ARP_hwdst=j[ARP].hwdst#Ether_adresses.index(j[ARP].hwdst)+1
                    ARP_pdst=j[ARP].pdst#IP_adresses.index(j[ARP].pdst)+1


                else:
                    ARP_hwtype=0
                    ARP_ptype=0
                    ARP_hwlen=0
                    ARP_plen=0
                    ARP_op=0
                    ARP_hwsrc=0
                    ARP_psrc=0
                    ARP_hwdst=0
                    ARP_pdst=0            


                if j.haslayer(LLC):
                    LLC_dsap=j[LLC].dsap
                    LLC_ssap=j[LLC].ssap
                    LLC_ctrl=j[LLC].ctrl
                else:
                    LLC_dsap=0
                    LLC_ssap=0
                    LLC_ctrl=0            



                if j.haslayer(EAPOL):
                    EAPOL_version=j[EAPOL].version
                    EAPOL_type=j[EAPOL].type
                    EAPOL_len=j[EAPOL].len

                else:
                    EAPOL_version=0
                    EAPOL_type=0
                    EAPOL_len=0            


                if j.haslayer(IP):

                    IP_Z = 0
                    IP_MF= 0
                    IP_DF= 0

                    IP_version=j[IP].version
                    IP_ihl=j[IP].ihl
                    IP_tos=j[IP].tos
                    IP_len=j[IP].len
                    IP_id=j[IP].id
                    IP_flags=j[IP].flags

                    IP_frag=j[IP].frag
                    IP_ttl=j[IP].ttl
                    IP_proto=j[IP].proto
                    IP_chksum=j[IP].chksum


                    #if j[IP].options!=0:
                    IP_options=j[IP].options
                    if "IPOption_Router_Alert"   in str(IP_options):
                        IP_options=1
                    else:IP_options=0



                    #if IP_flags not in ipf: ipf.append(IP_flags)

                    if IP_flags & Z:IP_Z = 1
                    if IP_flags & MF:IP_MF = 1
                    if IP_flags & DF:IP_DF = 1
                    #if "Flag" in str(IP_flags):
                        #IP_flags=str(IP_flags)
                        #temp=IP_flags.find("(")
                        #IP_flags=int(IP_flags[6:temp-1])




                    IP_src=j[IP].src#IP_adresses.index(j[IP].src)+1
                    IP_dst=j[IP].dst#IP_adresses.index(j[IP].dst)+1                



                else:
                    IP_Z = 0
                    IP_MF= 0
                    IP_DF= 0

                    IP_version=0
                    IP_ihl=0
                    IP_tos=0
                    IP_len=0
                    IP_id=0
                    IP_flags=0
                    IP_frag=0
                    IP_ttl=0
                    IP_proto=0
                    IP_chksum=0
                    IP_src=0
                    IP_dst=0
                    IP_options=0
                    IP_add_count=0            

                if j.haslayer(ICMP):
                    ICMP_type=j[ICMP].type
                    ICMP_code=j[ICMP].code
                    ICMP_chksum=j[ICMP].chksum
                    ICMP_id=j[ICMP].id
                    ICMP_seq=j[ICMP].seq
                    ICMP_ts_ori=j[ICMP].ts_ori
                    ICMP_ts_rx=j[ICMP].ts_rx
                    ICMP_ts_tx=j[ICMP].ts_tx
                    ICMP_gw=j[ICMP].gw
                    ICMP_ptr=j[ICMP].ptr
                    ICMP_reserved=j[ICMP].reserved
                    ICMP_length=j[ICMP].length
                    ICMP_addr_mask=j[ICMP].addr_mask
                    ICMP_nexthopmtu=j[ICMP].nexthopmtu
                    ICMP_unused=j[ICMP].unused
                else:
                    ICMP_type=0
                    ICMP_code=0
                    ICMP_chksum=0
                    ICMP_id=0
                    ICMP_seq=0
                    ICMP_ts_ori=0
                    ICMP_ts_rx=0
                    ICMP_ts_tx=0
                    ICMP_gw=0
                    ICMP_ptr=0
                    ICMP_reserved=0
                    ICMP_length=0
                    ICMP_addr_mask=0
                    ICMP_nexthopmtu=0
                    ICMP_unused=0




                if j.haslayer(TCP):
                    TCP_FIN = 0
                    TCP_SYN = 0
                    TCP_RST = 0
                    TCP_PSH = 0
                    TCP_ACK = 0
                    TCP_URG = 0
                    TCP_ECE = 0
                    TCP_CWR = 0
                    TCP_sport=j[TCP].sport
                    TCP_dport=j[TCP].dport
                    TCP_seq=j[TCP].seq
                    TCP_ack=j[TCP].ack
                    TCP_dataofs=j[TCP].dataofs
                    TCP_reserved=j[TCP].reserved
                    TCP_flags=j[TCP].flags

                    TCP_window=j[TCP].window
                    TCP_chksum=j[TCP].chksum
                    TCP_urgptr=j[TCP].urgptr
                    TCP_options=j[TCP].options
                    TCP_options= str(TCP_options).replace(",","-")
                    if TCP_options!="0":
                        TCP_options=1
                    else:
                        TCP_options=0




                    #if TCP_flags not in tcpf:
                        #tcpf.append(TCP_flags)
                    #print(TCP_options)
                    if TCP_flags & FIN:TCP_FIN = 1
                    if TCP_flags & SYN:TCP_SYN = 1
                    if TCP_flags & RST:TCP_RST = 1
                    if TCP_flags & PSH:TCP_PSH = 1
                    if TCP_flags & ACK:TCP_ACK = 1
                    if TCP_flags & URG:TCP_URG = 1
                    if TCP_flags & ECE:TCP_ECE = 1
                    if TCP_flags & CWR:TCP_CWR = 1   
                    #print(TCP_flags)
                    #if "Flag" in str(TCP_flags):
                        #TCP_flags=str(TCP_flags)
                        #temp=TCP_flags.find("(")
                        #TCP_flags=int(TCP_flags[6:temp-1])




                else:
                    TCP_sport=0
                    TCP_dport=0
                    TCP_seq=0
                    TCP_ack=0
                    TCP_dataofs=0
                    TCP_reserved=0
                    TCP_flags=0
                    TCP_window=0
                    TCP_chksum=0
                    TCP_urgptr=0
                    TCP_options=0
                    TCP_options=0
                    TCP_FIN = 0
                    TCP_SYN = 0
                    TCP_RST = 0
                    TCP_PSH = 0
                    TCP_ACK = 0
                    TCP_URG = 0
                    TCP_ECE = 0
                    TCP_CWR = 0


                if j.haslayer(UDP):
                    UDP_sport=j[UDP].sport
                    UDP_dport=j[UDP].dport
                    UDP_len=j[UDP].len
                    UDP_chksum=j[UDP].chksum
                else:
                    UDP_sport=0
                    UDP_dport=0
                    UDP_len=0
                    UDP_chksum=0





                if j.haslayer(DHCP):
                    DHCP_options=str(j[DHCP].options)
                    DHCP_options=DHCP_options.replace(",","-")
                    if "message" in DHCP_options:
                        x = DHCP_options.find(")")
                        DHCP_options=int(DHCP_options[x-1])

                else:
                    DHCP_options=0            


                if j.haslayer(BOOTP):
                    BOOTP_op=j[BOOTP].op
                    BOOTP_htype=j[BOOTP].htype
                    BOOTP_hlen=j[BOOTP].hlen
                    BOOTP_hops=j[BOOTP].hops
                    BOOTP_xid=j[BOOTP].xid
                    BOOTP_secs=j[BOOTP].secs
                    BOOTP_flags=j[BOOTP].flags
                    #if "Flag" in str(BOOTP_flags):BOOTP_flags=str(BOOTP_flags)temp=BOOTP_flags.find("(") BOOTP_flags=int(BOOTP_flags[6:temp-1])
                    BOOTP_ciaddr=j[BOOTP].ciaddr
                    BOOTP_yiaddr=j[BOOTP].yiaddr
                    BOOTP_siaddr=j[BOOTP].siaddr
                    BOOTP_giaddr=j[BOOTP].giaddr
                    BOOTP_chaddr=j[BOOTP].chaddr
                    BOOTP_sname=str(j[BOOTP].sname)
                    if BOOTP_sname!="0":
                        BOOTP_sname=1
                    else:
                        BOOTP_sname=0
                    BOOTP_file=str(j[BOOTP].file)
                    if BOOTP_file!="0":
                        BOOTP_file=1
                    else:
                        BOOTP_file=0

                    BOOTP_options=str(j[BOOTP].options)
                    BOOTP_options=BOOTP_options.replace(",","-")
                    if BOOTP_options!="0":
                        BOOTP_options=1
                    else:
                        BOOTP_options=0
                else:
                    BOOTP_op=0
                    BOOTP_htype=0
                    BOOTP_hlen=0
                    BOOTP_hops=0
                    BOOTP_xid=0
                    BOOTP_secs=0
                    BOOTP_flags=0
                    BOOTP_ciaddr=0
                    BOOTP_yiaddr=0
                    BOOTP_siaddr=0
                    BOOTP_giaddr=0
                    BOOTP_chaddr=0
                    BOOTP_sname=0
                    BOOTP_file=0
                    BOOTP_options=0






                if j.haslayer(DNS):
                    DNS_length=j[DNS].length
                    DNS_id=j[DNS].id
                    DNS_qr=j[DNS].qr
                    DNS_opcode=j[DNS].opcode
                    DNS_aa=j[DNS].aa
                    DNS_tc=j[DNS].tc
                    DNS_rd=j[DNS].rd
                    DNS_ra=j[DNS].ra
                    DNS_z=j[DNS].z
                    DNS_ad=j[DNS].ad
                    DNS_cd=j[DNS].cd
                    DNS_rcode=j[DNS].rcode
                    DNS_qdcount=j[DNS].qdcount
                    DNS_ancount=j[DNS].ancount
                    DNS_nscount=j[DNS].nscount
                    DNS_arcount=j[DNS].arcount
                    DNS_qd=str(j[DNS].qd).replace(",","-")
                    if DNS_qd!="0":
                        DNS_qd=1
                    else:
                        DNS_qd=0
                    DNS_an=str(j[DNS].an).replace(",","-")
                    if DNS_an!="0":
                        DNS_an=1
                    else:
                        DNS_an=0
                    DNS_ns=str(j[DNS].ns).replace(",","-")
                    if DNS_ns!="0":
                        DNS_ns=1
                    else:
                        DNS_ns=0
                    DNS_ar=str(j[DNS].ar).replace(",","-")
                    if DNS_ar!="0":
                        DNS_ar=1
                    else:
                        DNS_ar=0
                else:
                    DNS_length=0
                    DNS_id=0
                    DNS_qr=0
                    DNS_opcode=0
                    DNS_aa=0
                    DNS_tc=0
                    DNS_rd=0
                    DNS_ra=0
                    DNS_z=0
                    DNS_ad=0
                    DNS_cd=0
                    DNS_rcode=0
                    DNS_qdcount=0
                    DNS_ancount=0
                    DNS_nscount=0
                    DNS_arcount=0
                    DNS_qd=0
                    DNS_an=0
                    DNS_ns=0
                    DNS_ar=0





                pdata=[]
                if "TCP" in j:            
                    pdata = (j[TCP].payload)
                if "Raw" in j:
                    pdata = (j[Raw].load)
                elif "UDP" in j:            
                    pdata = (j[UDP].payload)
                elif "ICMP" in j:            
                    pdata = (j[ICMP].payload)
                pdata=list(memoryview(bytes(pdata)))            

                if pdata!=[]:
                    entropy=shannon(pdata)        
                else:
                    entropy=0
                payload_bytes=len(pdata)

                sport_class=port_class(TCP_sport+UDP_sport)
                dport_class=port_class(TCP_dport+UDP_dport)
                sport23=port_1023(TCP_sport+UDP_sport)
                dport23=port_1023(TCP_dport+UDP_dport)
                sport_bare=TCP_sport+UDP_sport
                dport_bare=TCP_dport+UDP_dport#port_class(TCP_dport+UDP_dport)


                Mac=str(j.src)          
                #Mac = Mac.replace('\\x',':')
                #Mac=Mac[3:-1]



                line=[ts,
                      Ether_dst,
                Ether_src,
                IP_src,
                IP_dst,
                pck_size,
                Ether_type,
                LLC_dsap,
                LLC_ssap,
                LLC_ctrl,
                EAPOL_version,
                EAPOL_type,
                EAPOL_len,
                IP_version,
                IP_ihl,
                IP_tos,
                IP_len,
                IP_flags,
                IP_Z,
                IP_MF,
                IP_id,
                IP_chksum,
                IP_DF  ,
                IP_frag,
                IP_ttl,
                IP_proto,
                IP_options,
                ICMP_type,
                ICMP_code,
                ICMP_chksum,
                ICMP_id,
                ICMP_seq,
                ICMP_ts_ori,
                ICMP_ts_rx,
                ICMP_ts_tx,
                ICMP_ptr,
                ICMP_reserved,
                ICMP_length,
                #ICMP_addr_mask,
                ICMP_nexthopmtu,
                ICMP_unused,
                TCP_seq,
                TCP_ack,
                TCP_dataofs,
                TCP_reserved,
                TCP_flags,
                TCP_FIN,
                TCP_SYN,
                TCP_RST,
                TCP_PSH,
                TCP_ACK,
                TCP_URG,
                TCP_ECE,
                TCP_CWR   ,
                TCP_window,
                TCP_chksum,
                TCP_urgptr,
                TCP_options,
                UDP_len,
                UDP_chksum,
                DHCP_options,
                BOOTP_op,
                BOOTP_htype,
                BOOTP_hlen,
                BOOTP_hops,
                BOOTP_xid,
                BOOTP_secs,
                BOOTP_flags,
                BOOTP_sname,
                BOOTP_file,
                BOOTP_options,
                DNS_length,
                DNS_id,
                DNS_qr,
                DNS_opcode,
                DNS_aa,
                DNS_tc,
                DNS_rd,
                DNS_ra,
                DNS_z,
                DNS_ad,
                DNS_cd,
                DNS_rcode,
                DNS_qdcount,
                DNS_ancount,
                DNS_nscount,
                DNS_arcount,
                sport_class,
                dport_class,
                sport23,
                dport23,
                sport_bare,
                dport_bare,
                TCP_sport,
                TCP_dport,
                UDP_sport,
                UDP_dport, 
                payload_bytes,
                entropy]

                #print(line)
                line=str(line).replace("[","")
                line=str(line).replace("]","")
                #line=str(line).replace("\',","-")
                line=str(line).replace(", ",",")
                line=str(line).replace("\'","")
                line=str(line).replace("None","0")
                if Mac in MAC_list:
                    Label=MAC_list[Mac][1]
                else:
                    Label=Mac
                ths.write(str(line)+f",{Label}\n")  
                label_count+=1
                #kk=line.split(",")
                #print(len(kk))
                #if len(kk)==112:
                #ths.write(line+"\n")

                #else:print(line)
        name=isim.replace("\\","/")
        output=filename.replace("_FE.csv","_WS.csv")

        if " " not in name:
            command=f"tshark -r {name}  -T fields -e _ws.col.Source -e _ws.col.Destination  -e _ws.col.Protocol    -E header=y -E separator=, -E quote=d -E occurrence=f >{output}"
        else:
            command=f"tshark -r \"{name}\" -T fields -e _ws.col.Source -e _ws.col.Destination  -e _ws.col.Protocol    -E header=y -E separator=, -E quote=d -E occurrence=f >\"{output}\""
        os.system(command)
        ths.close()          
    if len(file_list)>1:
        merged_csv(i,keyword)
# Out:
# 1/36-pcaps\Wans_Cam\2019-07-04.pcap
#   0%|                                                                                       | 0/353098 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   1%|▍                                                                          | 2080/353098 [00:05<13:40, 427.95it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   1%|▉                                                                          | 4141/353098 [00:09<14:21, 404.89it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   2%|█▎                                                                         | 6306/353098 [00:15<12:49, 450.48it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   2%|█▊                                                                         | 8413/353098 [00:20<16:41, 344.12it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   3%|██▏                                                                       | 10542/353098 [00:25<12:40, 450.55it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   4%|██▋                                                                       | 12633/353098 [00:30<12:49, 442.51it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   4%|███                                                                       | 14726/353098 [00:35<14:03, 401.14it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   5%|███▌                                                                      | 16759/353098 [00:40<12:39, 442.86it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   5%|███▉                                                                      | 18727/353098 [00:45<12:53, 432.35it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   6%|████▎                                                                     | 20813/353098 [00:50<11:45, 470.97it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   6%|████▊                                                                     | 22924/353098 [00:55<13:02, 421.89it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   7%|█████▏                                                                    | 25003/353098 [01:00<10:50, 504.55it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   8%|█████▋                                                                    | 27056/353098 [01:04<13:53, 391.33it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#   8%|█████▋                                                                    | 27097/353098 [01:05<13:46, 394.55it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   8%|██████                                                                    | 29144/353098 [01:10<12:37, 427.65it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   9%|██████▌                                                                   | 31187/353098 [01:15<13:04, 410.50it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#   9%|██████▉                                                                   | 33182/353098 [01:19<13:26, 396.83it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  10%|███████▍                                                                  | 35281/353098 [01:25<12:33, 421.90it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  11%|███████▊                                                                  | 37292/353098 [01:30<13:08, 400.33it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  11%|████████▏                                                                 | 39314/353098 [01:35<13:18, 392.95it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  12%|████████▋                                                                 | 41356/353098 [01:40<12:46, 406.95it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  12%|█████████                                                                 | 43378/353098 [01:45<13:28, 383.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  13%|█████████▌                                                                | 45435/353098 [01:50<12:30, 409.96it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  13%|█████████▉                                                                | 47445/353098 [01:55<13:30, 377.02it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  14%|██████████▎                                                               | 49477/353098 [02:00<12:16, 412.43it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  15%|██████████▊                                                               | 51570/353098 [02:05<12:19, 407.73it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  15%|███████████▏                                                              | 53653/353098 [02:10<12:14, 407.64it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  16%|███████████▋                                                              | 55732/353098 [02:15<11:56, 415.31it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  16%|████████████                                                              | 57732/353098 [02:20<12:01, 409.44it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  17%|████████████▌                                                             | 59783/353098 [02:25<12:20, 396.18it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  17%|████████████▉                                                             | 61761/353098 [02:30<12:11, 398.24it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#  18%|████████████▉                                                             | 61807/353098 [02:30<11:54, 407.85it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  18%|█████████████▍                                                            | 63894/353098 [02:35<11:38, 414.23it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  19%|█████████████▊                                                            | 66003/353098 [02:40<11:14, 425.89it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  19%|██████████████▎                                                           | 68068/353098 [02:45<11:46, 403.58it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  20%|██████████████▋                                                           | 70100/353098 [02:50<11:39, 404.75it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  20%|███████████████                                                           | 72113/353098 [02:55<11:35, 404.15it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  21%|███████████████▌                                                          | 74095/353098 [03:00<11:30, 403.87it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  22%|███████████████▉                                                          | 76076/353098 [03:05<12:41, 363.87it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  22%|████████████████▎                                                         | 78103/353098 [03:10<11:52, 385.84it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  23%|████████████████▊                                                         | 80121/353098 [03:15<11:05, 409.91it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  23%|█████████████████▏                                                        | 82102/353098 [03:20<11:47, 383.11it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  24%|█████████████████▋                                                        | 84132/353098 [03:25<11:32, 388.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  24%|██████████████████                                                        | 86250/353098 [03:30<10:24, 427.32it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  25%|██████████████████▍                                                       | 88250/353098 [03:35<11:16, 391.74it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  25%|██████████████████▌                                                       | 88290/353098 [03:35<11:24, 386.96it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  26%|██████████████████▉                                                       | 90262/353098 [03:40<10:47, 406.03it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  26%|███████████████████▎                                                      | 92329/353098 [03:45<10:50, 401.16it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  27%|███████████████████▊                                                      | 94461/353098 [03:50<10:32, 408.99it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  27%|████████████████████▏                                                     | 96456/353098 [03:55<10:16, 416.50it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  28%|████████████████████▋                                                     | 98551/353098 [04:00<10:25, 406.81it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  28%|████████████████████▊                                                    | 100568/353098 [04:05<10:11, 412.72it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  29%|█████████████████████▏                                                   | 102606/353098 [04:10<10:36, 393.35it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  30%|█████████████████████▋                                                   | 104695/353098 [04:15<09:35, 431.68it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  30%|██████████████████████                                                   | 106805/353098 [04:20<09:15, 443.09it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  31%|██████████████████████▍                                                  | 108780/353098 [04:25<10:28, 388.58it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  31%|██████████████████████▉                                                  | 110861/353098 [04:30<10:05, 399.89it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  32%|███████████████████████▎                                                 | 112977/353098 [04:35<09:26, 424.03it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  33%|███████████████████████▊                                                 | 115106/353098 [04:40<09:24, 421.39it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  33%|████████████████████████▏                                                | 117200/353098 [04:45<09:56, 395.44it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  34%|████████████████████████▋                                                | 119200/353098 [04:50<09:10, 424.63it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  34%|█████████████████████████                                                | 121200/353098 [04:55<09:07, 423.62it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  35%|█████████████████████████▍                                               | 123271/353098 [05:00<10:14, 373.79it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  35%|█████████████████████████▉                                               | 125348/353098 [05:05<09:58, 380.63it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  36%|██████████████████████████▎                                              | 127397/353098 [05:10<09:18, 403.87it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  37%|██████████████████████████▊                                              | 129510/353098 [05:15<07:58, 466.83it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  37%|███████████████████████████▏                                             | 131557/353098 [05:20<09:33, 386.47it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  38%|███████████████████████████▌                                             | 133561/353098 [05:25<09:01, 405.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  38%|████████████████████████████                                             | 135567/353098 [05:30<09:02, 401.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  39%|████████████████████████████▍                                            | 137492/353098 [05:35<09:11, 390.72it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  40%|████████████████████████████▊                                            | 139515/353098 [05:40<08:55, 398.59it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  40%|█████████████████████████████▏                                           | 141445/353098 [05:45<08:06, 435.09it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  41%|█████████████████████████████▋                                           | 143548/353098 [05:50<08:21, 418.02it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  41%|██████████████████████████████                                           | 145536/353098 [05:55<09:32, 362.53it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  42%|██████████████████████████████▌                                          | 147552/353098 [06:00<08:22, 409.05it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  42%|██████████████████████████████▉                                          | 149686/353098 [06:05<07:14, 467.70it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  43%|███████████████████████████████▎                                         | 151735/353098 [06:10<07:31, 445.80it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  44%|███████████████████████████████▊                                         | 153832/353098 [06:15<07:42, 430.93it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  44%|████████████████████████████████▏                                        | 155935/353098 [06:20<07:45, 423.86it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  45%|████████████████████████████████▋                                        | 158012/353098 [06:25<07:35, 428.54it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  45%|█████████████████████████████████▏                                       | 160274/353098 [06:30<07:28, 429.94it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  46%|█████████████████████████████████▌                                       | 162463/353098 [06:35<06:40, 476.43it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  47%|██████████████████████████████████                                       | 164718/353098 [06:40<06:33, 478.67it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  47%|██████████████████████████████████▌                                      | 166885/353098 [06:45<06:38, 467.68it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  48%|██████████████████████████████████▉                                      | 169035/353098 [06:50<07:17, 420.52it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  48%|███████████████████████████████████▎                                     | 170984/353098 [06:55<07:43, 393.11it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  49%|███████████████████████████████████▋                                     | 172919/353098 [07:00<07:10, 418.71it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  50%|████████████████████████████████████▏                                    | 175115/353098 [07:05<06:31, 454.64it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  50%|████████████████████████████████████▋                                    | 177253/353098 [07:10<07:15, 403.48it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  51%|█████████████████████████████████████                                    | 179363/353098 [07:15<06:49, 424.49it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  51%|█████████████████████████████████████▌                                   | 181423/353098 [07:20<07:19, 390.32it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  52%|█████████████████████████████████████▉                                   | 183438/353098 [07:25<06:35, 428.85it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  53%|██████████████████████████████████████▍                                  | 185716/353098 [07:30<06:32, 425.98it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  53%|██████████████████████████████████████▊                                  | 187787/353098 [07:35<06:36, 417.16it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  54%|███████████████████████████████████████▎                                 | 190073/353098 [07:40<06:28, 419.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  54%|███████████████████████████████████████▋                                 | 192114/353098 [07:45<07:30, 357.46it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  55%|████████████████████████████████████████                                 | 194044/353098 [07:50<06:37, 399.94it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  56%|████████████████████████████████████████▌                                | 196140/353098 [07:55<06:44, 387.89it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  56%|████████████████████████████████████████▉                                | 198264/353098 [08:00<06:17, 409.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  57%|█████████████████████████████████████████▍                               | 200273/353098 [08:05<06:56, 367.05it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  57%|█████████████████████████████████████████▊                               | 202283/353098 [08:10<06:03, 414.36it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  58%|██████████████████████████████████████████▏                              | 204347/353098 [08:15<06:01, 411.38it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  58%|██████████████████████████████████████████▋                              | 206526/353098 [08:20<05:34, 438.30it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  59%|███████████████████████████████████████████                              | 208586/353098 [08:25<05:49, 413.40it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  60%|███████████████████████████████████████████▌                             | 210840/353098 [08:30<05:11, 457.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  60%|████████████████████████████████████████████                             | 213119/353098 [08:35<05:05, 458.91it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  61%|████████████████████████████████████████████▍                            | 215241/353098 [08:40<05:22, 427.10it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  62%|████████████████████████████████████████████▉                            | 217493/353098 [08:45<05:09, 437.92it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  62%|█████████████████████████████████████████████▍                           | 219559/353098 [08:50<05:23, 412.29it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  63%|█████████████████████████████████████████████▊                           | 221798/353098 [08:55<05:07, 426.88it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  63%|█████████████████████████████████████████████▊                           | 221841/353098 [08:55<05:11, 421.98it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  63%|██████████████████████████████████████████████▎                          | 224086/353098 [09:00<04:50, 443.68it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  64%|██████████████████████████████████████████████▊                          | 226259/353098 [09:05<05:14, 402.77it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  65%|███████████████████████████████████████████████▏                         | 228303/353098 [09:10<04:35, 452.63it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  65%|███████████████████████████████████████████████▋                         | 230629/353098 [09:15<03:33, 573.04it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  66%|████████████████████████████████████████████████▏                        | 232882/353098 [09:20<04:31, 442.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  67%|████████████████████████████████████████████████▌                        | 235014/353098 [09:25<04:39, 422.77it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  67%|█████████████████████████████████████████████████                        | 237082/353098 [09:30<04:41, 412.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#  67%|█████████████████████████████████████████████████                        | 237124/353098 [09:30<04:40, 413.60it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  68%|█████████████████████████████████████████████████▍                       | 239195/353098 [09:35<04:30, 421.86it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  68%|█████████████████████████████████████████████████▊                       | 241204/353098 [09:40<04:23, 425.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  69%|██████████████████████████████████████████████████▎                      | 243274/353098 [09:45<04:39, 393.48it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  69%|██████████████████████████████████████████████████▋                      | 245345/353098 [09:50<04:07, 434.78it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  70%|███████████████████████████████████████████████████▏                     | 247459/353098 [09:55<04:13, 416.05it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  71%|███████████████████████████████████████████████████▌                     | 249501/353098 [10:00<04:11, 411.55it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  71%|████████████████████████████████████████████████████                     | 251644/353098 [10:05<04:04, 415.12it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  72%|████████████████████████████████████████████████████▍                    | 253596/353098 [10:10<04:07, 402.06it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  72%|████████████████████████████████████████████████████▊                    | 255583/353098 [10:15<04:10, 389.32it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  72%|████████████████████████████████████████████████████▊                    | 255635/353098 [10:15<03:52, 419.71it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  73%|█████████████████████████████████████████████████████▎                   | 257698/353098 [10:20<03:30, 454.01it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  74%|█████████████████████████████████████████████████████▋                   | 259698/353098 [10:25<03:43, 418.53it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  74%|██████████████████████████████████████████████████████                   | 261784/353098 [10:30<03:35, 423.97it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  74%|██████████████████████████████████████████████████████▏                  | 261827/353098 [10:30<03:42, 410.29it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  75%|██████████████████████████████████████████████████████▌                  | 264035/353098 [10:35<03:02, 488.63it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  75%|███████████████████████████████████████████████████████                  | 266172/353098 [10:40<03:30, 413.86it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  76%|███████████████████████████████████████████████████████▍                 | 268303/353098 [10:45<03:27, 409.63it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  77%|███████████████████████████████████████████████████████▉                 | 270418/353098 [10:50<03:24, 403.38it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  77%|███████████████████████████████████████████████████████▉                 | 270459/353098 [10:50<03:27, 397.55it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  77%|████████████████████████████████████████████████████████▎                | 272660/353098 [10:55<03:08, 427.73it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  78%|████████████████████████████████████████████████████████▊                | 274746/353098 [11:00<03:11, 408.41it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  78%|█████████████████████████████████████████████████████████▏               | 276843/353098 [11:05<02:57, 430.45it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  79%|█████████████████████████████████████████████████████████▋               | 278968/353098 [11:10<02:47, 442.87it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  80%|██████████████████████████████████████████████████████████▏              | 281195/353098 [11:15<02:56, 408.18it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  80%|██████████████████████████████████████████████████████████▌              | 283170/353098 [11:20<02:49, 413.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  81%|██████████████████████████████████████████████████████████▉              | 285191/353098 [11:25<02:53, 392.33it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  81%|███████████████████████████████████████████████████████████▍             | 287228/353098 [11:30<02:38, 416.61it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  81%|███████████████████████████████████████████████████████████▍             | 287271/353098 [11:30<02:40, 409.30it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  82%|███████████████████████████████████████████████████████████▊             | 289251/353098 [11:35<02:45, 385.00it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  82%|████████████████████████████████████████████████████████████▏            | 291258/353098 [11:40<02:33, 403.09it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  83%|████████████████████████████████████████████████████████████▋            | 293284/353098 [11:45<02:29, 399.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  84%|█████████████████████████████████████████████████████████████            | 295361/353098 [11:50<02:18, 415.51it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  84%|█████████████████████████████████████████████████████████████▍           | 297335/353098 [11:55<02:30, 371.14it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  85%|█████████████████████████████████████████████████████████████▉           | 299370/353098 [12:00<02:12, 406.46it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  85%|██████████████████████████████████████████████████████████████▎          | 301391/353098 [12:05<02:05, 411.29it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  86%|██████████████████████████████████████████████████████████████▋          | 303454/353098 [12:10<01:58, 418.11it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  87%|███████████████████████████████████████████████████████████████▏         | 305538/353098 [12:15<01:51, 428.00it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  87%|███████████████████████████████████████████████████████████████▌         | 307608/353098 [12:20<01:48, 421.11it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  88%|████████████████████████████████████████████████████████████████         | 309697/353098 [12:25<01:44, 413.59it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  88%|████████████████████████████████████████████████████████████████▍        | 311841/353098 [12:30<01:41, 407.12it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  89%|████████████████████████████████████████████████████████████████▉        | 313901/353098 [12:35<01:39, 393.98it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  89%|█████████████████████████████████████████████████████████████████▎       | 315864/353098 [12:40<01:32, 403.98it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#  89%|█████████████████████████████████████████████████████████████████▎       | 315905/353098 [12:40<01:34, 394.46it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  90%|█████████████████████████████████████████████████████████████████▋       | 317882/353098 [12:45<01:29, 394.13it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  91%|██████████████████████████████████████████████████████████████████       | 319782/353098 [12:50<01:30, 366.45it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  91%|██████████████████████████████████████████████████████████████████▌      | 321810/353098 [12:55<01:19, 395.71it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|██████████████████████████████████████████████████████████████████▉      | 323862/353098 [13:00<01:07, 430.34it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|███████████████████████████████████████████████████████████████████▎     | 325870/353098 [13:05<01:06, 410.61it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|███████████████████████████████████████████████████████████████████▊     | 327864/353098 [13:10<01:01, 407.01it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|████████████████████████████████████████████████████████████████████▏    | 329862/353098 [13:15<00:55, 414.97it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  94%|████████████████████████████████████████████████████████████████████▌    | 331921/353098 [13:20<00:51, 407.75it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  95%|█████████████████████████████████████████████████████████████████████    | 333782/353098 [13:25<00:53, 364.39it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  95%|█████████████████████████████████████████████████████████████████████▍   | 335717/353098 [13:30<00:46, 377.57it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  95%|█████████████████████████████████████████████████████████████████████▍   | 335755/353098 [13:30<00:49, 352.32it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
# ...
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  82%|████████████████████████████████████████████████████████████             | 297235/361326 [11:55<02:41, 397.24it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
#  82%|████████████████████████████████████████████████████████████             | 297279/361326 [11:55<02:41, 396.87it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  83%|████████████████████████████████████████████████████████████▍            | 299406/361326 [12:00<02:18, 446.75it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  83%|████████████████████████████████████████████████████████████▉            | 301481/361326 [12:05<02:18, 432.82it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  84%|█████████████████████████████████████████████████████████████▎           | 303606/361326 [12:10<02:12, 435.46it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  85%|█████████████████████████████████████████████████████████████▊           | 305745/361326 [12:15<02:11, 423.69it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  85%|██████████████████████████████████████████████████████████████▏          | 307861/361326 [12:20<01:58, 451.85it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  86%|██████████████████████████████████████████████████████████████▌          | 309916/361326 [12:25<02:06, 405.12it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  86%|██████████████████████████████████████████████████████████████▌          | 309958/361326 [12:26<02:08, 398.34it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  86%|███████████████████████████████████████████████████████████████          | 312105/361326 [12:30<01:54, 428.72it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  87%|███████████████████████████████████████████████████████████████▌         | 314307/361326 [12:35<01:48, 434.15it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  88%|███████████████████████████████████████████████████████████████▉         | 316543/361326 [12:41<02:01, 367.53it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  88%|████████████████████████████████████████████████████████████████▍        | 318684/361326 [12:45<01:36, 442.18it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  89%|████████████████████████████████████████████████████████████████▉        | 321304/361326 [12:51<01:22, 485.76it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  90%|█████████████████████████████████████████████████████████████████▎       | 323489/361326 [12:56<01:29, 424.65it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  90%|█████████████████████████████████████████████████████████████████▉       | 326478/361326 [13:01<00:37, 935.15it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  91%|██████████████████████████████████████████████████████████████████▋      | 330350/361326 [13:06<01:03, 488.35it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  92%|███████████████████████████████████████████████████████████████████▏     | 332792/361326 [13:11<01:01, 460.88it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|███████████████████████████████████████████████████████████████████▋     | 335191/361326 [13:15<00:57, 457.55it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  93%|████████████████████████████████████████████████████████████████████▏    | 337357/361326 [13:21<00:55, 431.63it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  94%|████████████████████████████████████████████████████████████████████▌    | 339626/361326 [13:26<00:50, 431.50it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  95%|█████████████████████████████████████████████████████████████████████    | 341830/361326 [13:30<00:40, 483.00it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  95%|█████████████████████████████████████████████████████████████████████    | 341879/361326 [13:31<00:42, 458.65it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  95%|█████████████████████████████████████████████████████████████████████▌   | 344396/361326 [13:36<00:39, 426.95it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  96%|██████████████████████████████████████████████████████████████████████   | 346605/361326 [13:41<00:33, 437.06it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  97%|██████████████████████████████████████████████████████████████████████▍  | 348853/361326 [13:46<00:25, 480.33it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  97%|██████████████████████████████████████████████████████████████████████▉  | 351028/361326 [13:51<00:22, 455.91it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  98%|███████████████████████████████████████████████████████████████████████▍ | 353572/361326 [13:56<00:08, 929.22it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  99%|███████████████████████████████████████████████████████████████████████▉ | 356027/361326 [14:01<00:12, 414.11it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
#  99%|███████████████████████████████████████████████████████████████████████▉ | 356069/361326 [14:01<00:12, 410.38it/s]WARNING: more Calling str(pkt) on Python 3 makes no sense!
#  99%|████████████████████████████████████████████████████████████████████████▎| 358143/361326 [14:06<00:06, 503.12it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████▋| 359991/361326 [14:11<00:03, 368.27it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|█████████████████████████████████████████████████████████████████████████| 361326/361326 [14:14<00:00, 422.85it/s]
# 17/36-pcaps\Wemo_SmartPlug\2019-06-29.pcap
#   0%|                                                                                         | 0/4273 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4273/4273 [00:02<00:00, 2125.82it/s]
# 18/36-pcaps\Wemo_SmartPlug\2019-07-01.pcap
#  59%|████████████████████████████████████████████▊                               | 2544/4314 [00:01<00:00, 2760.04it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4314/4314 [00:02<00:00, 1917.27it/s]
# 19/36-pcaps\Wemo_SmartPlug\2019-07-02.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3757/3757 [00:01<00:00, 2058.16it/s]
# 20/36-pcaps\Wemo_SmartPlug\2019-07-03.pcap
#   0%|                                                                                         | 0/3502 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3502/3502 [00:01<00:00, 1999.10it/s]
# 21/36-pcaps\Wemo_SmartPlug\2019-07-04.pcap
#  89%|███████████████████████████████████████████████████████████████████▎        | 3249/3670 [00:01<00:00, 1651.03it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3670/3670 [00:01<00:00, 1987.31it/s]
# 22/36-pcaps\Wemo_SmartPlug\2019-07-05.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3875/3875 [00:02<00:00, 1813.80it/s]
# 23/36-pcaps\Wemo_SmartPlug\2019-07-06.pcap
#   0%|                                                                                         | 0/3569 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3569/3569 [00:01<00:00, 1807.33it/s]
# 24/36-pcaps\Wemo_SmartPlug\2019-07-07.pcap
#  63%|███████████████████████████████████████████████▋                            | 2420/3854 [00:01<00:00, 2116.50it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3854/3854 [00:02<00:00, 1917.09it/s]
# 25/36-pcaps\Wemo_SmartPlug\2019-07-08.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3863/3863 [00:01<00:00, 1955.82it/s]
# 26/36-pcaps\Wemo_SmartPlug\2019-07-09.pcap
#   0%|                                                                                         | 0/3850 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3850/3850 [00:01<00:00, 1955.31it/s]
# 27/36-pcaps\Wemo_SmartPlug\2019-07-10.pcap
#  61%|██████████████████████████████████████████████▍                             | 2440/3989 [00:01<00:00, 1917.02it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3989/3989 [00:02<00:00, 1968.98it/s]
# 28/36-pcaps\Wemo_SmartPlug\2019-07-11.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 4061/4061 [00:01<00:00, 2047.75it/s]
# 29/36-pcaps\Wemo_SmartPlug\2019-07-12.pcap
#   0%|                                                                                         | 0/3980 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3980/3980 [00:02<00:00, 1834.28it/s]
# 30/36-pcaps\Wemo_SmartPlug\2019-07-13.pcap
#  60%|█████████████████████████████████████████████▋                              | 2237/3723 [00:01<00:00, 2091.73it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3723/3723 [00:01<00:00, 2029.36it/s]
# 31/36-pcaps\Wemo_SmartPlug\2019-07-14.pcap
#  88%|███████████████████████████████████████████████████████████████████▎        | 3840/4339 [00:02<00:00, 1283.17it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4339/4339 [00:02<00:00, 1729.38it/s]
# 32/36-pcaps\Wemo_SmartPlug\2019-07-15.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3933/3933 [00:02<00:00, 1892.59it/s]
# 33/36-pcaps\Wemo_SmartPlug\2019-07-16.pcap
#   0%|                                                                                         | 0/3913 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 3913/3913 [00:02<00:00, 1844.27it/s]
# 34/36-pcaps\Wemo_SmartPlug\2019-07-17.pcap
#  57%|███████████████████████████████████████████▎                                | 2410/4229 [00:01<00:00, 2398.58it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4229/4229 [00:02<00:00, 1983.37it/s]
# 35/36-pcaps\Wemo_SmartPlug\2019-07-18.pcap
# 100%|████████████████████████████████████████████████████████████████████████████| 3986/3986 [00:02<00:00, 1962.02it/s]
# 36/36-pcaps\Wemo_SmartPlug\2019-07-19.pcap
#   0%|                                                                                         | 0/4142 [00:00<?, ?it/s]WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: Calling str(pkt) on Python 3 makes no sense!
# WARNING: more Calling str(pkt) on Python 3 makes no sense!
# 100%|████████████████████████████████████████████████████████████████████████████| 4142/4142 [00:02<00:00, 1851.27it/s]

# %%
#405/440-pcaps\Wans_Cam\2019-07-04.pcap

# %% [markdown]
# # WIRESHARK FEATURES dst,src and Protocol added

# %%
name_list=find_the_way('./pcaps','_WS.csv')

for i in name_list:
    df=pd.read_csv(i)
    df=df[df["_ws.col.Protocol"]!="ARP"]
    df.to_csv(i,index=None)

# %%
name_list=find_the_way('./pcaps','_FE.csv')
name_list
# Out:
# ['./pcaps\\Chime_Doorbell\\2019-06-29_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-01_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-02_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-03_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-04_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-05_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-06_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-07_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-08_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-09_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-10_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-11_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-12_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-13_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-14_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-15_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-16_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-17_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-18_FE.csv',
#  './pcaps\\Chime_Doorbell\\2019-07-19_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-06-29_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-01_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-02_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-03_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-04_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-05_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-06_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-07_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-08_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-09_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-10_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-11_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-12_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-13_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-14_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-15_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-16_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-17_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-18_FE.csv',
#  './pcaps\\D-Link_Cam936L\\2019-07-19_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-06-29_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-01_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-02_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-03_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-04_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-05_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-06_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-07_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-08_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-09_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-10_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-11_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-12_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-13_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-14_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-15_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-16_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-17_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-18_FE.csv',
#  './pcaps\\Gosuna_LightBulb\\2019-07-19_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-06-29_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-01_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-02_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-03_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-04_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-05_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-06_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-07_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-08_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-09_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-10_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-11_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-12_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-13_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-14_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-15_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-16_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-17_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-18_FE.csv',
#  './pcaps\\Gosuna_Socket\\2019-07-19_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-06-29_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-01_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-02_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-03_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-04_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-05_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-06_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-07_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-08_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-09_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-10_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-11_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-12_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-13_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-14_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-15_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-16_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-17_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-18_FE.csv',
#  './pcaps\\Goumia_Coffemaker\\2019-07-19_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-06-29_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-01_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-02_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-03_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-04_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-05_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-06_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-07_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-08_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-09_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-10_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-11_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-12_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-13_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-14_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-15_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-16_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-17_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-18_FE.csv',
#  './pcaps\\itTiot_Cam\\2019-07-19_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-06-29_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-01_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-02_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-03_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-04_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-05_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-06_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-07_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-08_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-09_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-10_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-11_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-12_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-13_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-14_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-15_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-16_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-17_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-18_FE.csv',
#  './pcaps\\LaCrosse_AlarmClock\\2019-07-19_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-06-29_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-01_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-02_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-03_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-04_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-05_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-06_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-07_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-08_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-09_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-10_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-11_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-12_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-13_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-14_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-15_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-16_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-17_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-18_FE.csv',
#  './pcaps\\Lumiman_Bulb600\\2019-07-19_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-06-29_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-01_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-02_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-03_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-04_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-05_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-06_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-07_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-08_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-09_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-10_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-11_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-12_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-13_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-14_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-15_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-16_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-17_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-18_FE.csv',
#  './pcaps\\Lumiman_Bulb900\\2019-07-19_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\Lumiman_SmartPlug\\2019-07-19_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-06-29_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-01_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-02_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-03_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-04_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-05_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-06_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-07_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-08_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-09_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-10_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-11_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-12_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-13_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-14_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-15_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-16_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-17_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-18_FE.csv',
#  './pcaps\\Minger_LightStrip\\2019-07-19_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-06-29_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-01_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-02_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-03_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-04_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-05_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-06_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-07_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-08_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-09_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-10_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-11_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-12_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-13_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-14_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-15_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-16_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-17_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-18_FE.csv',
#  './pcaps\\Ocean_Radio\\2019-07-19_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\oossxx_SmartPlug\\2019-07-19_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\Renpho_SmartPlug\\2019-07-19_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-06-29_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-01_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-02_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-03_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-04_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-05_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-06_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-07_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-08_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-09_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-10_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-11_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-12_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-13_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-14_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-15_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-16_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-17_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-18_FE.csv',
#  './pcaps\\Ring_Doorbell\\2019-07-19_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-06-29_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-01_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-02_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-03_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-04_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-05_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-06_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-07_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-08_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-09_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-10_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-11_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-12_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-13_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-14_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-15_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-16_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-17_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-18_FE.csv',
#  './pcaps\\Smart_Lamp\\2019-07-19_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-06-29_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-01_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-02_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-03_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-04_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-05_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-06_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-07_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-08_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-09_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-10_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-11_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-12_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-13_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-14_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-15_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-16_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-17_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-18_FE.csv',
#  './pcaps\\Smart_LightStrip\\2019-07-19_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-06-29_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-01_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-02_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-03_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-04_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-05_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-06_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-07_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-08_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-09_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-10_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-11_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-12_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-13_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-14_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-15_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-16_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-17_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-18_FE.csv',
#  './pcaps\\Tenvis_Cam\\2019-07-19_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-06-29_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-01_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-02_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-03_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-04_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-05_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-06_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-07_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-08_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-09_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-10_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-11_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-12_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-13_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-14_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-15_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-16_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-17_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-18_FE.csv',
#  './pcaps\\tp-link_LightBulb\\2019-07-19_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\tp-link_SmartPlug\\2019-07-19_FE.csv',
#  './pcaps\\Wans_Cam\\2019-06-29_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-01_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-02_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-03_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-04_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-05_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-06_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-07_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-08_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-09_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-10_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-11_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-12_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-13_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-14_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-15_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-16_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-17_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-18_FE.csv',
#  './pcaps\\Wans_Cam\\2019-07-19_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-06-29_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-01_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-02_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-03_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-04_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-05_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-06_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-07_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-08_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-09_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-10_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-11_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-12_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-13_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-14_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-15_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-16_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-17_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-18_FE.csv',
#  './pcaps\\Wemo_SmartPlug\\2019-07-19_FE.csv']

# %%
for i in tqdm(name_list):
    df=pd.read_csv(i)
    WS_s_d=i.replace("_FE.csv","_WS.csv")
    s_d=pd.read_csv(WS_s_d)
    df["WS_src"]=s_d["_ws.col.Source"]
    df["WS_dst"]=s_d["_ws.col.Destination"]
    df["Protocol"]=s_d["_ws.col.Protocol"]
    y=df["Label"]
    df["MAC"]=df["Ether_src"]
    del df["Label"]
    df["Label"]=y
    df.to_csv(i,index=None) 
    flag_fixer(i)
    os.remove(WS_s_d)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 440/440 [41:09<00:00,  5.61s/it]

# %%
#!shutdown /s /t 1000

# %%
# !shutdown /s /t 1000
# Out:
# A system shutdown has already been scheduled.(1190)
